# %% [markdown]
# # 🔍 Revue de Code Terraform
#
# Notebook pour effectuer des revues complètes de code Terraform.
#
# **Fonctionnalités:**
# - 🔒 Audit de sécurité (secrets, permissions, chiffrement)
# - 📋 Conformité aux standards (nommage, variables, documentation)
# - 🎨 Qualité du code (style, clarté, optimisations)
# - 📚 Base de connaissances des best practices Terraform
#
# **Workflow:**
# 1. Initialiser les composants (une fois)
# 2. Lancer une revue avec `reviewer.review(path)`
# 3. Consulter le rapport détaillé
#
# **Modèles:**
# - Revue: Qwen2.5-coder (Ollama)
# - Embeddings: nomic-embed-text (Ollama)

# %% [markdown]
# ## 1️⃣ Initialisation

# %%
# Configuration de base
import sys
import logging
from pathlib import Path
from dotenv import load_dotenv

# Charger les variables d'environnement
load_dotenv()

# Ajouter le projet au path
project_root = Path.cwd().parent
sys.path.insert(0, str(project_root))

# Configuration du logging
logging.basicConfig(
    level=logging.INFO,
    format='%(asctime)s - %(levelname)s - %(message)s',
    datefmt='%H:%M:%S'
)

print("✅ Configuration de base chargée")
# Out:
# ✅ Configuration de base chargée

# %%
# Imports des modules du projet
from terraform_agent import (
    Config,
    KnowledgeBase,
    PromptManager,
    TerraformReviewer
)

print("✅ Modules importés")
# Out:
# 09:45:48 - INFO - 📋 Ensuring phoenix working directory: /Users/melkouhen/.phoenix
# 09:45:49 - INFO - setup plugin alembic.autogenerate.schemas
# 09:45:49 - INFO - setup plugin alembic.autogenerate.tables
# 09:45:49 - INFO - setup plugin alembic.autogenerate.types
# 09:45:49 - INFO - setup plugin alembic.autogenerate.constraints
# 09:45:49 - INFO - setup plugin alembic.autogenerate.defaults
# 09:45:49 - INFO - setup plugin alembic.autogenerate.comments
# ✅ Modules importés

# %%
# Initialisation des composants
print("⏳ Initialisation en cours...\n")

# Configuration
config = Config(base_dir=project_root)
print(f"✓ Configuration")
print(f"  - Project root: {config.PROJECT_ROOT}")
print(f"  - Work dir: {config.WORK_DIR}")
print(f"  - Review model: {config.REVIEW_MODEL_NAME}\n")

# Base de connaissances
knowledge_base = KnowledgeBase(config=config)
print("\n✓ Base de connaissances indexée\n")

# Prompts
prompts = PromptManager(config=config)
print("✓ Prompts chargés\n")

# Reviewer
reviewer = TerraformReviewer(
    config=config,
    knowledge_base=knowledge_base,
    prompts=prompts
)
print("✓ Reviewer initialisé\n")

print("="*60)
print("🎉 Tous les composants sont prêts !")
print("="*60)
# Out:
# 09:45:50 - INFO - Clearing 121 existing documents from vectorstore
# ⏳ Initialisation en cours...
#
# ✓ Configuration
#   - Project root: /Users/melkouhen/audit-tools/test-langchain
#   - Work dir: /Users/melkouhen/audit-tools/test-langchain/work
#   - Review model: qwen2.5-coder:7b-instruct
#
# 📚 Loading knowledge base...
#   ✓ Loaded 12 document(s) from /Users/melkouhen/audit-tools/test-langchain/rules
#   ✓ Split into 121 chunks
#   Creating new vectorstore database...
#   🗑️ Clearing 121 existing documents...
#   Indexing 121 documents...
# 09:45:53 - INFO - HTTP Request: POST http://127.0.0.1:11434/api/embed "HTTP/1.1 200 OK"
# 09:45:53 - INFO - TerraformReviewer initialized with model: qwen2.5-coder:7b-instruct
#   ✓ Vectorstore created and indexed
#
# ✓ Base de connaissances indexée
#
# ✓ Prompts chargés
#
# ✓ Reviewer initialisé
#
# ============================================================
# 🎉 Tous les composants sont prêts !
# ============================================================

# %% [markdown]
# ## 2️⃣ Revue de Code

# %% [markdown]
# ### Exemple 1: Revue Standard

# %%
# Chemin du code à analyser
code_path = str(config.WORK_DIR / "envs/dev")

# Vérifier que le chemin existe
if Path(code_path).exists():
    tf_files = list(Path(code_path).glob("*.tf"))
    print(f"✅ Chemin trouvé: {code_path}")
    print(f"📄 Fichiers: {len(tf_files)} fichiers .tf")
    for f in tf_files:
        size_kb = f.stat().st_size / 1024
        print(f"   - {f.name} ({size_kb:.1f} KB)")
else:
    print(f"⚠️  Chemin introuvable: {code_path}")
    print(f"\nChemins disponibles:")
    for item in config.WORK_DIR.rglob("*.tf"):
        print(f"   - {item.parent}")
# Out:
# ✅ Chemin trouvé: /Users/melkouhen/audit-tools/test-langchain/work/envs/dev
# 📄 Fichiers: 3 fichiers .tf
#    - outputs.tf (0.4 KB)
#    - main.tf (0.4 KB)
#    - variables.tf (0.7 KB)

# %%
# Lancer la revue complète
report = reviewer.review(code_path, verbose=True)

# Afficher le rapport
print("\n" + "="*80)
print("📋 RAPPORT DE REVUE")
print("="*80 + "\n")
print(report)
# Out:
# 09:45:53 - INFO - ================================================================================
# 09:45:53 - INFO - Starting code review for: /Users/melkouhen/audit-tools/test-langchain/work/envs/dev
# 09:45:53 - INFO - ================================================================================
# 09:45:53 - INFO - Searching knowledge base with query: 'terraform best practices'
# 09:45:53 - INFO - HTTP Request: POST http://127.0.0.1:11434/api/embed "HTTP/1.1 200 OK"
# 09:45:53 - INFO - Retrieved 4596 chars of best practices
# 09:45:53 - INFO - Found 3 .tf files
# 09:45:53 - INFO - Total code to review: 1534 bytes across 3 files
# 09:45:53 - INFO - Preparing review prompt
# 09:45:53 - INFO - Running code review with qwen2.5-coder:7b-instruct
# 09:45:53 - INFO - Prompt size: 9612 chars
# 📚 Step 1: Retrieving best practices...
#   ✓ Retrieved 4596 chars
#
# 📖 Step 2: Reading Terraform files...
#   ✓ Read 3 files (1534 chars)
#
# 🤖 Step 3: Executing code review...
# 09:46:07 - INFO - HTTP Request: POST http://127.0.0.1:11434/api/chat "HTTP/1.1 200 OK"
# 09:46:36 - INFO - Code review completed in 43.07s
# 09:46:36 - INFO - Response length: 2698 chars
# 09:46:36 - WARNING - Issues found during review
# 09:46:36 - INFO - Fixed code provided in response
# 09:46:36 - INFO - ================================================================================
# 09:46:36 - INFO - Code review completed in 43.13s
# 09:46:36 - INFO - ================================================================================
#   ✓ Review completed
#
# 📝 Step 4: Formatting results...
#
# ================================================================================
# 📋 RAPPORT DE REVUE
# ================================================================================
#
# ✅ REVUE COMPLÉTÉE - CORRECTIONS REQUISES
#
# **Statut:** 🔴 Corrections Nécessaires
#
# **Fichiers analysés:** 3 fichiers
#
# ---
#
# ## Détails de la Revue
#
# ## RÉSULTATS DE REVUE
#
# ❌ Corrections nécessaires
#
# **Fichiers analysés:** 3
# **Problèmes:**
# - 🔴 CRITIQUE: 1
# - 🟠 MAJEUR: 2
# - 🟡 MINEUR: 0
#
# ### Problèmes Détectés
#
# #### Problème 1
# - **Fichier:** `main.tf`:4
# - **Règle:** TF-NO-HARDCODED-REGION
# - **Description:** La région est codée en dur (`europe-west9`).
#
# **Correction Suggérée:**
# ```hcl
# # main.tf
# module "gcs_bucket" {
#   source = "../../"
#
#   gcp_project_id           = var.gcp_project_id
#   gcp_region               = var.gcp_region
#   environment              = "dev"
#   bucket_prefix            = var.bucket_prefix
#   enable_versioning        = var.enable_versioning
#   force_destroy            = var.force_destroy
#   public_access_prevention = var.public_access_prevention
# }
# ```
# ```hcl
# # variables.tf
# variable "gcp_region" {
#   description = "GCP region for resources"
#   type        = string
#   default     = null
# }
#
# # terraform.tfvars (per environment)
# environment = "dev"
# gcp_region  = "europe-west9"
# ```
#
# #### Problème 2
# - **Fichier:** `variables.tf`:8
# - **Règle:** TF-NAMING
# - **Description:** La variable `bucket_Name` ne respecte pas la convention snake_case.
#
# **Correction Suggérée:**
# ```hcl
# # variables.tf
# variable "bucket_prefix" {
#   description = "Prefix for GCS bucket names"
#   type        = string
# }
# ```
#
# ### Code Corrigé
#
# **main.tf:**
# ```hcl
# module "gcs_bucket" {
#   source = "../../"
#
#   gcp_project_id           = var.gcp_project_id
#   gcp_region               = var.gcp_region
#   environment              = "dev"
#   bucket_prefix            = var.bucket_prefix
#   enable_versioning        = var.enable_versioning
#   force_destroy            = var.force_destroy
#   public_access_prevention = var.public_access_prevention
# }
# ```
#
# **variables.tf:**
# ```hcl
# variable "gcp_project_id" {
#   description = "GCP Project ID"
#   type        = string
# }
#
# variable "gcp_region" {
#   description = "GCP region for resources"
#   type        = string
#   default     = null
# }
#
# variable "bucket_prefix" {
#   description = "Prefix for GCS bucket names"
#   type        = string
# }
# ```
#
# **terraform.tfvars:**
# ```hcl
# environment = "dev"
# gcp_region  = "europe-west9"
# gcp_project_id = "my-company-prod"
# enable_versioning = true
# force_destroy = true
# public_access_prevention = "enforced"
# bucket_prefix = "my-bucket-prefix"
# ```
#
# **outputs.tf:**
# ```hcl
# output "bucket_name" {
#   description = "Name of the created GCS bucket"
#   value       = module.gcs_bucket.bucket_name
# }
#
# output "bucket_url" {
#   description = "Self-link URL of the GCS bucket"
#   value       = module.gcs_bucket.bucket_url
# }
#
# output "bucket_location" {
#   description = "Location of the GCS bucket"
#   value       = module.gcs_bucket.bucket_location
# }
# ```
#
# Veuillez corriger ces problèmes et valider le code à nouveau.
#
# ---
#
# ## Instructions de Correction
#
# ⚠️ **Les corrections doivent être appliquées à:** `/Users/melkouhen/audit-tools/test-langchain/work/envs/dev`
#
# **Processus:**
# 1. ✅ Appliquer les corrections CRITIQUE et MAJEUR
# 2. ✅ Relancer `terraform_init` → `terraform_validate` → `terraform_plan`
# 3. ✅ Relancer `review_and_fix_code` pour confirmer les corrections
# 4. ✅ Tous les logs sont dans `/Users/melkouhen/audit-tools/test-langchain/work/envs/dev/terraform_logs.error`
#
# **Critères de Succès:**
# - ✅ Tous les problèmes CRITIQUE corrigés
# - ✅ terraform validate passe (0 erreurs)
# - ✅ review_and_fix_code montre 0 CRITIQUE/MAJEUR
# - ✅ Logs complets en terraform_logs.error
#
# L'agent procèdera automatiquement à la correction, validation et revalidation.

# %% [markdown]
# ### Exemple 2: Revue Ciblée (Sécurité)

# %%
# Revue focalisée sur la sécurité
security_report = reviewer.review(
    path=code_path,
    query="terraform security best practices secrets encryption IAM",
    verbose=True
)

print("\n" + "="*80)
print("🔒 AUDIT DE SÉCURITÉ")
print("="*80 + "\n")
print(security_report)
# Out:
# 09:46:36 - INFO - ================================================================================
# 09:46:36 - INFO - Starting code review for: /Users/melkouhen/audit-tools/test-langchain/work/envs/dev
# 09:46:36 - INFO - ================================================================================
# 09:46:36 - INFO - Searching knowledge base with query: 'terraform security best practices secrets encryption IAM'
# 09:46:36 - INFO - HTTP Request: POST http://127.0.0.1:11434/api/embed "HTTP/1.1 200 OK"
# 09:46:36 - INFO - Retrieved 4485 chars of best practices
# 09:46:36 - INFO - Found 3 .tf files
# 09:46:36 - INFO - Total code to review: 1534 bytes across 3 files
# 09:46:36 - INFO - Preparing review prompt
# 09:46:36 - INFO - Running code review with qwen2.5-coder:7b-instruct
# 09:46:36 - INFO - Prompt size: 9501 chars
# 📚 Step 1: Retrieving best practices...
#   ✓ Retrieved 4485 chars
#
# 📖 Step 2: Reading Terraform files...
#   ✓ Read 3 files (1534 chars)
#
# 🤖 Step 3: Executing code review...
# 09:46:45 - INFO - HTTP Request: POST http://127.0.0.1:11434/api/chat "HTTP/1.1 200 OK"
# 09:47:28 - INFO - Code review completed in 51.27s
# 09:47:28 - INFO - Response length: 3949 chars
# 09:47:28 - WARNING - Issues found during review
# 09:47:28 - INFO - Fixed code provided in response
# 09:47:28 - INFO - ================================================================================
# 09:47:28 - INFO - Code review completed in 51.38s
# 09:47:28 - INFO - ================================================================================
#   ✓ Review completed
#
# 📝 Step 4: Formatting results...
#
# ================================================================================
# 🔒 AUDIT DE SÉCURITÉ
# ================================================================================
#
# ✅ REVUE COMPLÉTÉE - CORRECTIONS REQUISES
#
# **Statut:** 🔴 Corrections Nécessaires
#
# **Fichiers analysés:** 3 fichiers
#
# ---
#
# ## Détails de la Revue
#
# ## RÉSULTATS DE REVUE
#
# ❌ Corrections nécessaires
#
# **Fichiers analysés:** 3
# **Problèmes:**
# - 🔴 CRITIQUE: 1
# - 🟠 MAJEUR: 2
# - 🟡 MINEUR: 0
#
# ### Problèmes Détectés
#
# #### Problème 1
# - **Fichier:** main.tf:Ligne:65
# - **Règle:** TF-NO-HARDCODED-SECRETS
# - **Description:** La variable `gcp_project_id` est définie en dur.
#
# **Correction Suggérée:**
# ```hcl
# variable "gcp_project_id" {
#   description = "GCP Project ID"
#   type        = string
#   default     = null
# }
# ```
#
# #### Problème 2
# - **Fichier:** main.tf:Ligne:68
# - **Règle:** TF-NAMING
# - **Description:** La variable `bucket_prefix` est définie avec un nom en camelCase au lieu de snake_case.
#
# **Correction Suggérée:**
# ```hcl
# variable "bucket_prefix" {
#   description = "Prefix for GCS bucket names"
#   type        = string
# }
# ```
#
# ### Code Corrigé
#
# #### outputs.tf
# ```hcl
# output "bucket_name" {
#   description = "Name of the created GCS bucket"
#   value       = module.gcs_bucket.bucket_name
# }
#
# output "bucket_url" {
#   description = "Self-link URL of the GCS bucket"
#   value       = module.gcs_bucket.bucket_url
# }
#
# output "bucket_location" {
#   description = "Location of the GCS bucket"
#   value       = module.gcs_bucket.bucket_location
# }
# ```
#
# #### main.tf
# ```hcl
# module "gcs_bucket" {
#   source = "../../"
#
#   gcp_project_id           = var.gcp_project_id
#   gcp_region               = var.gcp_region
#   environment              = "dev"
#   bucket_prefix            = var.bucket_prefix
#   enable_versioning        = var.enable_versioning
#   force_destroy            = var.force_destroy
#   public_access_prevention = var.public_access_prevention
# }
#
# variable "gcp_project_id" {
#   description = "GCP Project ID"
#   type        = string
#   default     = null
# }
#
# variable "gcp_region" {
#   description = "GCP region for resources"
#   type        = string
#   default     = "europe-west9"
# }
#
# variable "bucket_prefix" {
#   description = "Prefix for GCS bucket names"
#   type        = string
# }
#
# variable "enable_versioning" {
#   description = "Enable versioning for storage buckets"
#   type        = bool
#   default     = true
# }
#
# variable "force_destroy" {
#   description = "Allow Terraform to delete non-empty buckets (safe for dev)"
#   type        = bool
#   default     = true
# }
#
# variable "public_access_prevention" {
#   description = "Enforce public access prevention"
#   type        = string
#   default     = "enforced"
# }
# ```
#
# #### variables.tf
# ```hcl
# variable "gcp_project_id" {
#   description = "GCP Project ID"
#   type        = string
# }
#
# variable "gcp_region" {
#   description = "GCP region for resources"
#   type        = string
#   default     = "europe-west9"
# }
#
# variable "bucket_prefix" {
#   description = "Prefix for GCS bucket names"
#   type        = string
# }
#
# variable "enable_versioning" {
#   description = "Enable versioning for storage buckets"
#   type        = bool
#   default     = true
# }
#
# variable "force_destroy" {
#   description = "Allow Terraform to delete non-empty buckets (safe for dev)"
#   type        = bool
#   default     = true
# }
#
# variable "public_access_prevention" {
#   description = "Enforce public access prevention"
#   type        = string
#   default     = "enforced"
# }
# ```
#
# ## Explications
#
# 1. **Problème 1 (TF-NO-HARDCODED-SECRETS):**
#    - La variable `gcp_project_id` est définie en dur dans la configuration actuelle, ce qui est une sécurité inacceptable. Il est préférable de passer cette valeur via des variables d'environnement ou des fichiers de variables séparés pour éviter le hardcoding.
#
# 2. **Problème 2 (TF-NAMING):**
#    - La variable `bucket_prefix` est nommée en camelCase, ce qui ne respecte pas la convention snake_case recommandée par Terraform et les normes de codage générales.
#
# **Correction Apportée:**
# - Nous avons corrigé le nom de la variable `bucket_prefix` pour qu'il respecte la convention snake_case.
# - Nous avons également ajouté une valeur par défaut à la variable `gcp_project_id`, ce qui permet aux utilisateurs de ne pas spécifier cette valeur et d'utiliser la valeur par défaut si nécessaire.
#
# ---
#
# ## Instructions de Correction
#
# ⚠️ **Les corrections doivent être appliquées à:** `/Users/melkouhen/audit-tools/test-langchain/work/envs/dev`
#
# **Processus:**
# 1. ✅ Appliquer les corrections CRITIQUE et MAJEUR
# 2. ✅ Relancer `terraform_init` → `terraform_validate` → `terraform_plan`
# 3. ✅ Relancer `review_and_fix_code` pour confirmer les corrections
# 4. ✅ Tous les logs sont dans `/Users/melkouhen/audit-tools/test-langchain/work/envs/dev/terraform_logs.error`
#
# **Critères de Succès:**
# - ✅ Tous les problèmes CRITIQUE corrigés
# - ✅ terraform validate passe (0 erreurs)
# - ✅ review_and_fix_code montre 0 CRITIQUE/MAJEUR
# - ✅ Logs complets en terraform_logs.error
#
# L'agent procèdera automatiquement à la correction, validation et revalidation.

# %% [markdown]
# ### Exemple 3: Revue Ciblée (Conformité)

# %%
# Revue focalisée sur la conformité
compliance_report = reviewer.review(
    path=code_path,
    query="terraform naming conventions variables outputs documentation",
    verbose=True
)

print("\n" + "="*80)
print("📋 AUDIT DE CONFORMITÉ")
print("="*80 + "\n")
print(compliance_report)
# Out:
# 09:47:28 - INFO - ================================================================================
# 09:47:28 - INFO - Starting code review for: /Users/melkouhen/audit-tools/test-langchain/work/envs/dev
# 09:47:28 - INFO - ================================================================================
# 09:47:28 - INFO - Searching knowledge base with query: 'terraform naming conventions variables outputs documentation'
# 09:47:28 - INFO - HTTP Request: POST http://127.0.0.1:11434/api/embed "HTTP/1.1 200 OK"
# 09:47:28 - INFO - Retrieved 4528 chars of best practices
# 09:47:28 - INFO - Found 3 .tf files
# 09:47:28 - INFO - Total code to review: 1534 bytes across 3 files
# 09:47:28 - INFO - Preparing review prompt
# 09:47:28 - INFO - Running code review with qwen2.5-coder:7b-instruct
# 09:47:28 - INFO - Prompt size: 9544 chars
# 📚 Step 1: Retrieving best practices...
#   ✓ Retrieved 4528 chars
#
# 📖 Step 2: Reading Terraform files...
#   ✓ Read 3 files (1534 chars)
#
# 🤖 Step 3: Executing code review...
# 09:47:37 - INFO - HTTP Request: POST http://127.0.0.1:11434/api/chat "HTTP/1.1 200 OK"
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[7], line 2
#       1 # Revue focalisée sur la conformité
# ----> 2 compliance_report = reviewer.review(
#       3     path=code_path,
#       4     query="terraform naming conventions variables outputs documentation",
#       5     verbose=True
#
# File ~/audit-tools/test-langchain/terraform_agent/reviewer.py:251, in TerraformReviewer.review(self, path, query, verbose)
#     248 if verbose:
#     249     print("🤖 Step 3: Executing code review...")
# --> 251 review_response = self.execute_review(best_practices, code_content, path)
#     253 if verbose:
#     254     print("  ✓ Review completed\n")
#
# File ~/audit-tools/test-langchain/terraform_agent/reviewer.py:152, in TerraformReviewer.execute_review(self, best_practices, code_content, path)
#     149 logger.info(f"Prompt size: {len(review_prompt)} chars")
#     151 start_time = time.time()
# --> 152 review_response = str(self.review_model.invoke(review_prompt).content)
#     153 elapsed = time.time() - start_time
#     155 logger.info(f"Code review completed in {elapsed:.2f}s")
#
# File ~/audit-tools/test-langchain/.venv/lib/python3.14/site-packages/langchain_core/language_models/chat_models.py:471, in BaseChatModel.invoke(self, input, config, stop, **kwargs)
#     457 @override
#     458 def invoke(
#     459     self,
#    (...)    464     **kwargs: Any,
#     465 ) -> AIMessage:
#     466     config = ensure_config(config)
#     467     return cast(
#     468         "AIMessage",
#     469         cast(
#     470             "ChatGeneration",
# --> 471             self.generate_prompt(
#     472                 [self._convert_input(input)],
#     473                 stop=stop,
#     474                 callbacks=config.get("callbacks"),
#     475                 tags=config.get("tags"),
#     476                 metadata=config.get("metadata"),
#     477                 run_name=config.get("run_name"),
#     478                 run_id=config.pop("run_id", None),
#     479                 **kwargs,
#     480             ).generations[0][0],
#     481         ).message,
#     482     )
#
# File ~/audit-tools/test-langchain/.venv/lib/python3.14/site-packages/langchain_core/language_models/chat_models.py:1749, in BaseChatModel.generate_prompt(self, prompts, stop, callbacks, **kwargs)
#    1740 @override
#    1741 def generate_prompt(
#    1742     self,
#    (...)   1746     **kwargs: Any,
#    1747 ) -> LLMResult:
#    1748     prompt_messages = [p.to_messages() for p in prompts]
# -> 1749     return self.generate(prompt_messages, stop=stop, callbacks=callbacks, **kwargs)
#
# File ~/audit-tools/test-langchain/.venv/lib/python3.14/site-packages/langchain_core/language_models/chat_models.py:1556, in BaseChatModel.generate(self, messages, stop, callbacks, tags, metadata, run_name, run_id, **kwargs)
#    1553 for i, m in enumerate(input_messages):
#    1554     try:
#    1555         results.append(
# -> 1556             self._generate_with_cache(
#    1557                 m,
#    1558                 stop=stop,
#    1559                 run_manager=run_managers[i] if run_managers else None,
#    1560                 **kwargs,
#    1561             )
#    1562         )
#    1563     except BaseException as e:
#    1564         if run_managers:
#
# File ~/audit-tools/test-langchain/.venv/lib/python3.14/site-packages/langchain_core/language_models/chat_models.py:1896, in BaseChatModel._generate_with_cache(self, messages, stop, run_manager, **kwargs)
#    1894     result = generate_from_stream(iter(chunks))
#    1895 elif inspect.signature(self._generate).parameters.get("run_manager"):
# -> 1896     result = self._generate(
#    1897         messages, stop=stop, run_manager=run_manager, **kwargs
#    1898     )
#    1899 else:
#    1900     result = self._generate(messages, stop=stop, **kwargs)
#
# File ~/audit-tools/test-langchain/.venv/lib/python3.14/site-packages/langchain_ollama/chat_models.py:1200, in ChatOllama._generate(self, messages, stop, run_manager, **kwargs)
#    1193 def _generate(
#    1194     self,
#    1195     messages: list[BaseMessage],
#    (...)   1198     **kwargs: Any,
#    1199 ) -> ChatResult:
# -> 1200     final_chunk = self._chat_stream_with_aggregation(
#    1201         messages, stop, run_manager, verbose=self.verbose, **kwargs
#    1202     )
#    1203     generation_info = final_chunk.generation_info
#    1204     chat_generation = ChatGeneration(
#    1205         message=AIMessage(
#    1206             content=final_chunk.text,
#    (...)   1213         generation_info=generation_info,
#    1214     )
#
# File ~/audit-tools/test-langchain/.venv/lib/python3.14/site-packages/langchain_ollama/chat_models.py:1135, in ChatOllama._chat_stream_with_aggregation(self, messages, stop, run_manager, verbose, **kwargs)
#    1126 def _chat_stream_with_aggregation(
#    1127     self,
#    1128     messages: list[BaseMessage],
#    (...)   1132     **kwargs: Any,
#    1133 ) -> ChatGenerationChunk:
#    1134     final_chunk = None
# -> 1135     for chunk in self._iterate_over_stream(messages, stop, **kwargs):
#    1136         if final_chunk is None:
#    1137             final_chunk = chunk
#
# File ~/audit-tools/test-langchain/.venv/lib/python3.14/site-packages/langchain_ollama/chat_models.py:1224, in ChatOllama._iterate_over_stream(self, messages, stop, **kwargs)
#    1217 def _iterate_over_stream(
#    1218     self,
#    1219     messages: list[BaseMessage],
#    1220     stop: list[str] | None = None,
#    1221     **kwargs: Any,
#    1222 ) -> Iterator[ChatGenerationChunk]:
#    1223     reasoning = kwargs.get("reasoning", self.reasoning)
# -> 1224     for stream_resp in self._create_chat_stream(messages, stop, **kwargs):
#    1225         if not isinstance(stream_resp, str):
#    1226             content = (
#    1227                 stream_resp["message"]["content"]
#    1228                 if "message" in stream_resp and "content" in stream_resp["message"]
#    1229                 else ""
#    1230             )
#
# File ~/audit-tools/test-langchain/.venv/lib/python3.14/site-packages/langchain_ollama/chat_models.py:1122, in ChatOllama._create_chat_stream(self, messages, stop, **kwargs)
#    1119 chat_params = self._chat_params(messages, stop, **kwargs)
#    1121 if chat_params["stream"]:
# -> 1122     yield from self._client.chat(**chat_params)
#    1123 else:
#    1124     yield self._client.chat(**chat_params)
#
# File ~/audit-tools/test-langchain/.venv/lib/python3.14/site-packages/ollama/_client.py:181, in Client._request.<locals>.inner()
#     178   e.response.read()
#     179   raise ResponseError(e.response.text, e.response.status_code) from None
# --> 181 for line in r.iter_lines():
#     182   part = json.loads(line)
#     183   if err := part.get('error'):
#
# File ~/audit-tools/test-langchain/.venv/lib/python3.14/site-packages/httpx/_models.py:929, in Response.iter_lines(self)
#     927 decoder = LineDecoder()
#     928 with request_context(request=self._request):
# --> 929     for text in self.iter_text():
#     930         for line in decoder.decode(text):
#     931             yield line
#
# File ~/audit-tools/test-langchain/.venv/lib/python3.14/site-packages/httpx/_models.py:916, in Response.iter_text(self, chunk_size)
#     914 chunker = TextChunker(chunk_size=chunk_size)
#     915 with request_context(request=self._request):
# --> 916     for byte_content in self.iter_bytes():
#     917         text_content = decoder.decode(byte_content)
#     918         for chunk in chunker.decode(text_content):
#
# File ~/audit-tools/test-langchain/.venv/lib/python3.14/site-packages/httpx/_models.py:897, in Response.iter_bytes(self, chunk_size)
#     895 chunker = ByteChunker(chunk_size=chunk_size)
#     896 with request_context(request=self._request):
# --> 897     for raw_bytes in self.iter_raw():
#     898         decoded = decoder.decode(raw_bytes)
#     899         for chunk in chunker.decode(decoded):
#
# File ~/audit-tools/test-langchain/.venv/lib/python3.14/site-packages/httpx/_models.py:951, in Response.iter_raw(self, chunk_size)
#     948 chunker = ByteChunker(chunk_size=chunk_size)
#     950 with request_context(request=self._request):
# --> 951     for raw_stream_bytes in self.stream:
#     952         self._num_bytes_downloaded += len(raw_stream_bytes)
#     953         for chunk in chunker.decode(raw_stream_bytes):
#
# File ~/audit-tools/test-langchain/.venv/lib/python3.14/site-packages/httpx/_client.py:153, in BoundSyncStream.__iter__(self)
#     152 def __iter__(self) -> typing.Iterator[bytes]:
# --> 153     for chunk in self._stream:
#     154         yield chunk
#
# File ~/audit-tools/test-langchain/.venv/lib/python3.14/site-packages/httpx/_transports/default.py:127, in ResponseStream.__iter__(self)
#     125 def __iter__(self) -> typing.Iterator[bytes]:
#     126     with map_httpcore_exceptions():
# --> 127         for part in self._httpcore_stream:
#     128             yield part
#
# File ~/audit-tools/test-langchain/.venv/lib/python3.14/site-packages/httpcore/_sync/connection_pool.py:407, in PoolByteStream.__iter__(self)
#     405 except BaseException as exc:
#     406     self.close()
# --> 407     raise exc from None
#
# File ~/audit-tools/test-langchain/.venv/lib/python3.14/site-packages/httpcore/_sync/connection_pool.py:403, in PoolByteStream.__iter__(self)
#     401 def __iter__(self) -> typing.Iterator[bytes]:
#     402     try:
# --> 403         for part in self._stream:
#     404             yield part
#     405     except BaseException as exc:
#
# File ~/audit-tools/test-langchain/.venv/lib/python3.14/site-packages/httpcore/_sync/http11.py:342, in HTTP11ConnectionByteStream.__iter__(self)
#     340 with ShieldCancellation():
#     341     self.close()
# --> 342 raise exc
#
# File ~/audit-tools/test-langchain/.venv/lib/python3.14/site-packages/httpcore/_sync/http11.py:334, in HTTP11ConnectionByteStream.__iter__(self)
#     332 try:
#     333     with Trace("receive_response_body", logger, self._request, kwargs):
# --> 334         for chunk in self._connection._receive_response_body(**kwargs):
#     335             yield chunk
#     336 except BaseException as exc:
#     337     # If we get an exception while streaming the response,
#     338     # we want to close the response (and possibly the connection)
#     339     # before raising that exception.
#
# File ~/audit-tools/test-langchain/.venv/lib/python3.14/site-packages/httpcore/_sync/http11.py:203, in HTTP11Connection._receive_response_body(self, request)
#     200 timeout = timeouts.get("read", None)
#     202 while True:
# --> 203     event = self._receive_event(timeout=timeout)
#     204     if isinstance(event, h11.Data):
#     205         yield bytes(event.data)
#
# File ~/audit-tools/test-langchain/.venv/lib/python3.14/site-packages/httpcore/_sync/http11.py:217, in HTTP11Connection._receive_event(self, timeout)
#     214     event = self._h11_state.next_event()
#     216 if event is h11.NEED_DATA:
# --> 217     data = self._network_stream.read(
#     218         self.READ_NUM_BYTES, timeout=timeout
#     219     )
#     221     # If we feed this case through h11 we'll raise an exception like:
#     222     #
#     223     #     httpcore.RemoteProtocolError: can't handle event type
#    (...)    227     # perspective. Instead we handle this case distinctly and treat
#     228     # it as a ConnectError.
#     229     if data == b"" and self._h11_state.their_state == h11.SEND_RESPONSE:
#
# File ~/audit-tools/test-langchain/.venv/lib/python3.14/site-packages/httpcore/_backends/sync.py:128, in SyncStream.read(self, max_bytes, timeout)
#     126 with map_exceptions(exc_map):
#     127     self._sock.settimeout(timeout)
# --> 128     return self._sock.recv(max_bytes)
#
# KeyboardInterrupt:

# %% [markdown]
# ## 3️⃣ Utilitaires

# %% [markdown]
# ### Scan Rapide (sans revue complète)

# %%
# Obtenir des statistiques rapides
stats = reviewer.quick_scan(code_path)

print("📊 Statistiques du Code\n")
print(f"Chemin: {stats['path']}")
print(f"Fichiers .tf: {stats['files']}")
print(f"Ressources: {stats['resources']}")
print(f"Variables: {stats['variables']}")
print(f"Outputs: {stats['outputs']}")
print(f"Lignes totales: {stats['total_lines']}")

# %% [markdown]
# ### Trouver tous les répertoires avec du code Terraform

# %%
# Lister tous les répertoires avec des fichiers .tf
def find_terraform_dirs():
    """Find all directories containing .tf files."""
    directories = set()
    for tf_file in config.WORK_DIR.rglob("*.tf"):
        directories.add(tf_file.parent)
    return sorted(directories)

terraform_dirs = find_terraform_dirs()

print(f"📁 Répertoires avec du code Terraform: {len(terraform_dirs)}\n")
for directory in terraform_dirs:
    tf_count = len(list(directory.glob("*.tf")))
    rel_path = directory.relative_to(config.WORK_DIR)
    print(f"  - {rel_path} ({tf_count} fichiers)")

# %% [markdown]
# ### Comparer plusieurs revues

# %%
def compare_reviews(path: str, queries: list[str]) -> dict:
    """
    Compare multiple reviews with different focus areas.
    
    Args:
        path: Path to Terraform code
        queries: List of queries for different aspects
        
    Returns:
        Dictionary mapping queries to review results
    """
    results = {}
    
    for i, query in enumerate(queries, 1):
        print(f"\n{'='*80}")
        print(f"Revue {i}/{len(queries)}: {query}")
        print("="*80)
        
        result = reviewer.review(path, query, verbose=False)
        results[query] = result
        
        # Analyser le résultat
        has_critical = "CRITIQUE" in result
        has_major = "MAJEUR" in result
        
        if has_critical:
            print("❌ Problèmes CRITIQUES détectés")
        elif has_major:
            print("⚠️  Problèmes MAJEURS détectés")
        else:
            print("✅ Code conforme")
    
    return results

# Exemple d'utilisation:
# queries = [
#     "terraform security best practices",
#     "terraform naming conventions",
#     "terraform documentation"
# ]
# comparison = compare_reviews(code_path, queries)

# %% [markdown]
# ## 4️⃣ Sauvegarde des Rapports

# %%
from datetime import datetime

def save_report(report: str, name: str = None, output_dir: Path = None) -> Path:
    """
    Save review report to file.
    
    Args:
        report: Review report content
        name: Custom name for report (optional)
        output_dir: Output directory (default: work/)
        
    Returns:
        Path to saved file
    """
    if output_dir is None:
        output_dir = config.WORK_DIR
    
    timestamp = datetime.now().strftime("%Y%m%d_%H%M%S")
    
    if name:
        filename = f"review_{name}_{timestamp}.md"
    else:
        filename = f"review_report_{timestamp}.md"
    
    filepath = output_dir / filename
    
    header = f"""# Rapport de Revue de Code Terraform

**Date:** {datetime.now().strftime('%Y-%m-%d %H:%M:%S')}
**Modèle:** {config.REVIEW_MODEL_NAME}
**Généré par:** TerraformReviewer

---

"""
    
    with open(filepath, 'w', encoding='utf-8') as f:
        f.write(header + report)
    
    size_kb = filepath.stat().st_size / 1024
    print(f"✅ Rapport sauvegardé: {filepath}")
    print(f"   Taille: {size_kb:.1f} KB")
    
    return filepath

# Exemples d'utilisation:
# save_report(report, name="standard")
# save_report(security_report, name="security")
# save_report(compliance_report, name="compliance")

# %% [markdown]
# ## 5️⃣ Revue avec Chemin Personnalisé

# %%
# Pour analyser un répertoire personnalisé
custom_path = "/chemin/vers/votre/code/terraform"

# Vérifier et scanner
# if Path(custom_path).exists():
#     stats = reviewer.quick_scan(custom_path)
#     print(f"Fichiers: {stats['files']}, Ressources: {stats['resources']}")
#     
#     # Lancer la revue
#     custom_report = reviewer.review(custom_path)
#     print(custom_report)
#     
#     # Sauvegarder
#     save_report(custom_report, name="custom")
# else:
#     print(f"Chemin introuvable: {custom_path}")

# %% [markdown]
# ---
#
# ## 📚 Guide d'Utilisation
#
# ### Workflow Standard
#
# ```python
# # 1. Initialiser (une fois)
# # Exécuter les cellules 1-3
#
# # 2. Revue simple
# report = reviewer.review("/path/to/terraform")
# print(report)
#
# # 3. Sauvegarder
# save_report(report)
# ```
#
# ### Types de Revues
#
# **Standard** - Best practices générales
# ```python
# reviewer.review(path)
# ```
#
# **Sécurité** - Audit de sécurité approfondi
# ```python
# reviewer.review(path, query="terraform security secrets encryption IAM")
# ```
#
# **Conformité** - Standards et conventions
# ```python
# reviewer.review(path, query="terraform naming conventions documentation")
# ```
#
# **Performance** - Optimisations et coûts
# ```python
# reviewer.review(path, query="terraform performance optimization cost")
# ```
#
# ### Outils Disponibles
#
# - `reviewer.review(path, query, verbose)` - Revue complète
# - `reviewer.quick_scan(path)` - Statistiques rapides
# - `save_report(report, name)` - Sauvegarde avec timestamp
# - `compare_reviews(path, queries)` - Comparaison multi-aspects
#
# ### Classification des Problèmes
#
# 🔴 **CRITIQUE** - Sécurité, runtime, perte de données (bloquant)
# 🟠 **MAJEUR** - Maintenabilité, performance, best practices
# 🟡 **MINEUR** - Style, optimisations optionnelles
#
# ### Troubleshooting
#
# **Ollama non lancé**
# ```bash
# ollama serve
# ```
#
# **Modèle manquant**
# ```bash
# ollama pull qwen2.5-coder:7b-instruct
# ollama pull nomic-embed-text
# ```
#
# **Logs détaillés**
# ```python
# import logging
# logging.getLogger('terraform_agent').setLevel(logging.DEBUG)
# ```
