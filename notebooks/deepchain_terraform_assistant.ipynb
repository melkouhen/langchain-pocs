# %%
# ============================================================================
# TERRAFORM CODE GENERATION & VALIDATION AGENT
# ============================================================================

from pathlib import Path
from dotenv import load_dotenv

# Load environment variables
load_dotenv()

# Import agent classes
import sys
sys.path.insert(0, str(Path.cwd().parent))

from terraform_agent import Config, PromptManager, KnowledgeBase, TerraformAgent

print("✓ All imports loaded successfully")
# Out:
# ✓ All imports loaded successfully

# %%
# ============================================================================
# INITIALIZE COMPONENTS
# ============================================================================

# Get project root (parent of notebooks directory)
project_root = Path.cwd().parent

# Initialize configuration
config = Config(base_dir=project_root)
print(f"Project Root: {config.PROJECT_ROOT}")
print(f"Work Dir: {config.WORK_DIR}")
print(f"Docs Dir: {config.DOCS_DIR}")

# Initialize prompt manager
prompts = PromptManager(config)
print("\n✓ Prompts loaded")

# Initialize knowledge base (loads and indexes docs)
knowledge_base = KnowledgeBase(config)

# Initialize agent
agent = TerraformAgent(config, prompts, knowledge_base)
# Out:
# Project Root: /Users/melkouhen/audit-tools/test-langchain
# Work Dir: /Users/melkouhen/audit-tools/test-langchain/work
# Docs Dir: /Users/melkouhen/audit-tools/test-langchain/docs
#
# ✓ Prompts loaded
# 📚 Loading knowledge base...
#   ✓ Loaded 2 document(s) from /Users/melkouhen/audit-tools/test-langchain/docs
#   ✓ Split into 9 chunks
#   ✓ Vectorstore found, loading existing database...
#   ✓ Vectorstore already indexed with 9 documents
#   ✓ Vectorstore created and indexed
# 🤖 Setting up agent...
#   ✓ System prompt loaded (4718 chars)
#   ✓ User prompt loaded (538 chars)
#   ✓ Agent created with tools:
#     - search (knowledge base)
#     - validate_and_fix_code
#     - review_and_fix_code

# %%
# ============================================================================
# EXECUTE AGENT
# ============================================================================

result = agent.run()
print(f"\n🎯 Agent Output:\n{result}")
# Out:
# 🛠️  Preparing workspace...
#   ✓ Cleaned existing work directory
#   ✓ Created fresh work directory: /Users/melkouhen/audit-tools/test-langchain/work
#
# 🚀 Starting Terraform Code Generation Agent
# ================================================================================
# Timestamp: 2026-05-07 15:25:03
# ================================================================================
#
# 📝 Agent is running...
#     (Agent will autonomously call: search, validate_and_fix_code, review_and_fix_code)
# --------------------------------------------------------------------------------
# ✅ SUCCESS
# --------------------------------------------------------------------------------
#
# 🎯 Agent Output:
# Excellent! Now let me create a summary document showing what was delivered:
#
# ## ✅ Production-Ready Terraform Project Complete
#
# Your GCS bucket Terraform project is ready for deployment. Here's what has been created:
#
# ### 📦 Project Structure
#
# ```
# /Users/melkouhen/audit-tools/test-langchain/work/
# ├── envs/
# │   ├── dev/
# │   │   ├── providers.tf                 (Terraform >= 1.5, GCP provider ~> 5.0)
# │   │   ├── variables.tf                 (All required & optional variables)
# │   │   ├── main.tf                      (GCS bucket resource)
# │   │   ├── outputs.tf                   (6 bucket outputs)
# │   │   ├── terraform.tfvars.example     (Variable template)
# │   │   └── terraform.tfstate            (Local state file)
# │   │
# │   └── prod/
# │       ├── providers.tf                 (Same configuration)
# │       ├── variables.tf                 (Same structure, different defaults)
# │       ├── main.tf                      (Same resource)
# │       ├── outputs.tf                   (Same outputs)
# │       ├── terraform.tfvars.example     (Variable template)
# │       └── terraform.tfstate            (Separate state file)
# │
# └── README.md                            (Complete deployment guide)
# ```
#
# ### 🎯 Key Features
#
# **Environment Isolation:**
# - ✅ Separate state files per environment (dev & prod)
# - ✅ Independent configurations with environment-specific defaults
# - ✅ Different bucket names: `my-bucket-elkouhen-dev` and `my-bucket-elkouhen-prod`
#
# **Security Best Practices:**
# - ✅ Uniform bucket-level access enabled
# - ✅ Public access prevention enforced
# - ✅ `prevent_destroy` lifecycle rule (protects against accidents)
# - ✅ Labels for resource tracking and cost allocation
#
# **Production-Ready:**
# - ✅ Version-constrained providers (Terraform ~> 1.5, GCP ~> 5.0)
# - ✅ All variables explicitly declared with descriptions
# - ✅ Comprehensive outputs for downstream consumption
# - ✅ No `timestamp()` or random functions (zero drift guarantee)
# - ✅ Code validated and passes best practices review
#
# **Dev vs Prod Differences:**
# | Feature | Dev | Prod |
# |---------|-----|------|
# | Versioning | Disabled | Enabled |
# | Bucket Name | `*-dev` | `*-prod` |
# | Access Control | Enforced | Enforced |
# | Retention Rules | None | Recommended to add |
#
# ### 🚀 Quick Deployment
#
# ```bash
# # 1. Authenticate
# gcloud auth application-default login
#
# # 2. Deploy Dev
# cd /Users/melkouhen/audit-tools/test-langchain/work/envs/dev
# cp terraform.tfvars.example terraform.tfvars
# # Edit terraform.tfvars with your GCP project ID
#
# terraform init
# terraform plan
# terraform apply
#
# # 3. Deploy Prod (optional)
# cd ../prod
# cp terraform.tfvars.example terraform.tfvars
# # Edit terraform.tfvars with your GCP project ID
# terraform init
# terraform plan
# terraform apply
# ```
#
# ### 📊 Available Outputs
#
# After deployment, retrieve values with:
# ```bash
# terraform output bucket_name
# terraform output bucket_url        # gs://my-bucket-elkouhen-dev
# terraform output bucket_self_link  # Full URI
# terraform output -json             # All outputs in JSON
# ```
#
# ### ✨ What's Included
#
# - ✅ **Complete provider configuration** with version constraints
# - ✅ **Fully parameterized** buckets (storage class, versioning, labels, etc.)
# - ✅ **Separate state management** per environment
# - ✅ **Production-grade security** (UBLA, public access prevention)
# - ✅ **Comprehensive documentation** (README with examples)
# - ✅ **Template variable files** for easy setup
# - ✅ **Code review passed** (compliant with Terraform best practices)
#
# All code is **syntax-validated** and **best-practices compliant**. Ready to deploy! 🎉
