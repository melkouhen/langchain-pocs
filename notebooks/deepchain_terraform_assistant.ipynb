# %%
# ============================================================================
# TERRAFORM CODE GENERATION & VALIDATION AGENT
# ============================================================================

from pathlib import Path
from dotenv import load_dotenv

# Load environment variables
load_dotenv()

# Import agent classes
import sys
sys.path.insert(0, str(Path.cwd().parent))

from terraform_agent import Config, PromptManager, KnowledgeBase, TerraformAgent

print("✓ All imports loaded successfully")
# Out:
# ✓ All imports loaded successfully

# %%
# ============================================================================
# CONFIGURE LOGGING
# ============================================================================

import logging

# Configure logging to see all DEBUG and above messages
logging.basicConfig(
    level=logging.INFO,
    format='%(asctime)s - %(name)s - %(levelname)s - %(message)s',
    datefmt='%H:%M:%S'
)

# Optional: Set specific loggers to DEBUG for more detail
logging.getLogger('terraform_agent').setLevel(logging.DEBUG)

print("✓ Logging configured - you will now see INFO level logs and above")

# %%
# ============================================================================
# INITIALIZE COMPONENTS
# ============================================================================

# Get project root (parent of notebooks directory)
project_root = Path.cwd().parent

# Initialize configuration
config = Config(base_dir=project_root)
print(f"Project Root: {config.PROJECT_ROOT}")
print(f"Work Dir: {config.WORK_DIR}")
print(f"Docs Dir: {config.RULES_DIR}")

# Initialize prompt manager
prompts = PromptManager(config)
print("\n✓ Prompts loaded")

# Initialize knowledge base (loads and indexes docs)
knowledge_base = KnowledgeBase(config)

# Initialize agent
agent = TerraformAgent(config, prompts, knowledge_base)
# Out:
# Project Root: /Users/melkouhen/audit-tools/test-langchain
# Work Dir: /Users/melkouhen/audit-tools/test-langchain/work
# Docs Dir: /Users/melkouhen/audit-tools/test-langchain/rules
#
# ✓ Prompts loaded
# 📚 Loading knowledge base...
#   ✓ Loaded 8 document(s) from /Users/melkouhen/audit-tools/test-langchain/rules
#   ✓ Split into 91 chunks
#   Creating new vectorstore database...
#   Indexing 91 documents...
#   ✓ Vectorstore created and indexed
# 🤖 Setting up agent...
#   ✓ System prompt loaded (8864 chars)
#   ✓ User prompt loaded (538 chars)
#   ✓ Agent created with tools:
#     - load_module_spec (module specifications)
#     - search_knowledge_base (best practices)
#     - terraform_init (initialize working directory)
#     - terraform_validate (validate configuration)
#     - terraform_plan (preview changes)
#     - review_and_fix_code (code review)

# %%
# ============================================================================
# EXECUTE AGENT
# ============================================================================

result = agent.run()
print(f"\n🎯 Agent Output:\n{result}")
# Out:
# 🛠️  Preparing workspace...
#
# 🚀 Starting Terraform Code Generation Agent
# ================================================================================
# Timestamp: 2026-05-11 12:52:30
# ================================================================================
#
# 📝 Agent is running...
#     (Agent will autonomously call: terraform_init, terraform_validate, terraform_plan, review_and_fix_code)
# --------------------------------------------------------------------------------
# ✅ SUCCESS
# --------------------------------------------------------------------------------
#
# 🎯 Agent Output:
# Perfect! Now let me create a final comprehensive summary for you:
#
# ---
#
# ## 🎉 **Project Complete: Production-Ready GCS Terraform Deployment**
#
# I've successfully generated a **production-ready Terraform project** for deploying Google Cloud Storage buckets with proper dev/prod environment isolation. Here's what was delivered:
#
# ### ✅ **Deliverables Summary**
#
# #### **1. Terraform Code (All Validated)**
# - ✅ **Dev Environment** (`envs/dev/`)
#   - Bucket: `my-bucket-elkouhen-dev`
#   - `force_destroy = true` (cleanup-friendly)
#   - 30-day lifecycle rule
#   - Versioning enabled
#
# - ✅ **Prod Environment** (`envs/prod/`)
#   - Bucket: `my-bucket-elkouhen-prod`
#   - `force_destroy = false` (accidental deletion protection)
#   - 90-day NEARLINE transition
#   - Versioning enabled + SLA label
#
# #### **2. Validation Status**
# | Check | Status |
# |-------|--------|
# | `terraform init` | ✅ Both environments |
# | `terraform validate` | ✅ Zero syntax errors |
# | `terraform plan` | ✅ Ready to create buckets |
# | Code review | ✅ Complies with best practices |
#
# #### **3. Best Practices Implemented**
# - ✅ **Environment Separation** (TF-ENV-SEPARATION-004): Folder-based with isolated state
# - ✅ **Version Pinning** (TF-VERSION-PINNING-006): Terraform ≥1.3, Google provider ~6.0
# - ✅ **No Hardcoding** (TF-AVOID-HARDCODING-011): All values parameterized in variables
# - ✅ **Security Defaults**: Public access prevention, versioning, IAM bindings parameterized
# - ✅ **Official Module**: Using `terraform-google-modules/cloud-storage/google` (~>12.3)
#
# #### **4. Documentation Generated**
# - 📄 **DEPLOYMENT_GUIDE.md**: Step-by-step instructions, troubleshooting, full configuration reference
# - 📄 **PROJECT_STATUS.md**: Validation results, deliverables checklist, pre-go-live review
# - 📄 **QUICK_REFERENCE.md**: 5-minute quick start guide
# - 📄 **knowledge/learned_gcs_production_deployment_2026-01-15.md**: Architectural decisions & learnings
#
# ### 🚀 **Quick Start (Your Next Steps)**
#
# ```bash
# # 1. Update your GCP project ID in both environments
# cd /Users/melkouhen/audit-tools/test-langchain/work/envs/dev
# sed -i '' 's/YOUR_GCP_PROJECT_ID/your-actual-project-id/g' terraform.tfvars
#
# cd ../prod
# sed -i '' 's/YOUR_GCP_PROJECT_ID/your-actual-project-id/g' terraform.tfvars
#
# # 2. Deploy dev
# cd ../dev && terraform apply
#
# # 3. Deploy prod
# cd ../prod && terraform apply
#
# # 4. Verify buckets
# gsutil ls
# ```
#
# ### 📁 **Project Structure**
# ```
# /Users/melkouhen/audit-tools/test-langchain/work/
# ├── envs/
# │   ├── dev/              # Dev: force_destroy=true, 30-day lifecycle
# │   │   ├── main.tf       ✅ GCS module configuration
# │   │   ├── variables.tf  ✅ All 14 variables declared
# │   │   ├── outputs.tf    ✅ bucket_names, bucket_urls, buckets object
# │   │   ├── providers.tf  ✅ Google provider pinned
# │   │   ├── backend.tf    ✅ Local state (ready for remote)
# │   │   └── terraform.tfvars ✅ Dev-specific values
# │   │
# │   └── prod/             # Prod: force_destroy=false, 90-day NEARLINE
# │       ├── main.tf       ✅ GCS module configuration
# │       ├── variables.tf  ✅ Same variables (safer defaults)
# │       ├── outputs.tf    ✅ Same outputs
# │       ├── providers.tf  ✅ Same provider config
# │       ├── backend.tf    ✅ Isolated state
# │       └── terraform.tfvars ✅ Prod-specific values
# │
# ├── knowledge/
# │   └── learned_gcs_production_deployment_2026-01-15.md ✅ Documented
# │
# ├── DEPLOYMENT_GUIDE.md   ✅ Comprehensive guide
# ├── PROJECT_STATUS.md     ✅ Validation & summary
# └── QUICK_REFERENCE.md    ✅ 5-minute start guide
# ```
#
# ### 🔐 **Security & Compliance**
# - ✅ **Public Access Prevention**: ENFORCED on both buckets
# - ✅ **Versioning**: ENABLED for recovery capability
# - ✅ **Force Destroy**: Dev=true (safe for testing), Prod=false (prevents accidents)
# - ✅ **IAM Bindings**: Parameterized (no hardcoded emails)
# - ✅ **Labels**: Applied for resource tracking (environment, managed-by, team)
# - ✅ **Lifecycle Rules**: Dev=30-day retention, Prod=90-day to NEARLINE (cost optimization)
#
# ### 📊 **Files Summary**
# - **Total Terraform files generated**: 12 (6 per environment)
# - **Lines of HCL**: ~400 across both environments
# - **Variables declared**: 14 (explicit, validated, with descriptions)
# - **Outputs exposed**: 4 per environment (bucket_names, urls, objects, environment)
# - **Documentation pages**: 4 (guides, learnings, status, quick reference)
#
# ### ✨ **Key Highlights**
# 1. **Zero hardcoded values** — All configuration parameterized
# 2. **Production safety** — Prod environment prevents accidental bucket deletion
# 3. **Cost optimization** — Lifecycle rules transition to cheaper storage automatically
# 4. **Team-ready** — Clear environment separation prevents cross-environment mistakes
# 5. **Fully documented** — Deployment guide, troubleshooting, architectural decisions all included
#
# You now have a **fully validated, documented, and production-ready Terraform project** that follows industry best practices for GCS bucket deployment across multiple environments! 🚀
