# %%
# ============================================================================
# TERRAFORM CODE GENERATION & VALIDATION AGENT
# ============================================================================

from pathlib import Path
from dotenv import load_dotenv

# Load environment variables
load_dotenv()

# Import agent classes
import sys
sys.path.insert(0, str(Path.cwd().parent))

from terraform_agent import Config, PromptManager, KnowledgeBase, TerraformAgent

print("✓ All imports loaded successfully")
# Out:
# ✓ All imports loaded successfully

# %%
# ============================================================================
# CONFIGURE LOGGING
# ============================================================================

import logging

# Configure logging to see all DEBUG and above messages
logging.basicConfig(
    level=logging.INFO,
    format='%(asctime)s - %(name)s - %(levelname)s - %(message)s',
    datefmt='%H:%M:%S'
)

# Optional: Set specific loggers to DEBUG for more detail
logging.getLogger('terraform_agent').setLevel(logging.DEBUG)

print("✓ Logging configured - you will now see INFO level logs and above")
# Out:
# ✓ Logging configured - you will now see INFO level logs and above

# %%
# ============================================================================
# INITIALIZE COMPONENTS
# ============================================================================

# Get project root (parent of notebooks directory)
project_root = Path.cwd().parent

# Initialize configuration
config = Config(base_dir=project_root)
print(f"Project Root: {config.PROJECT_ROOT}")
print(f"Work Dir: {config.WORK_DIR}")
print(f"Docs Dir: {config.RULES_DIR}")

# Initialize prompt manager
prompts = PromptManager(config)
print("\n✓ Prompts loaded")

# Initialize knowledge base (loads and indexes docs)
knowledge_base = KnowledgeBase(config)

# Initialize agent
agent = TerraformAgent(config, prompts, knowledge_base)
# Out:
# 14:00:49 - terraform_agent.tools - INFO - Initializing tools with config, prompts, and knowledge base
# 14:00:49 - terraform_agent.tools - INFO - Tools initialized - Review model: claude-haiku-4-5-20251001
# Project Root: /Users/melkouhen/audit-tools/test-langchain
# Work Dir: /Users/melkouhen/audit-tools/test-langchain/work
# Docs Dir: /Users/melkouhen/audit-tools/test-langchain/rules
#
# ✓ Prompts loaded
# 📚 Loading knowledge base...
#   ✓ Loaded 8 document(s) from /Users/melkouhen/audit-tools/test-langchain/rules
#   ✓ Split into 91 chunks
#   ✓ Vectorstore found, loading existing database...
#   ✓ Vectorstore already indexed with 91 documents
#   ✓ Vectorstore created and indexed
# 🤖 Setting up agent...
#   ✓ System prompt loaded (19389 chars)
#   ✓ User prompt loaded (2053 chars)
#   ✓ Agent created with tools:
#     - load_module_spec (module specifications)
#     - search_knowledge_base (best practices)
#     - terraform_init (initialize working directory)
#     - terraform_validate (validate configuration)
#     - terraform_plan (preview changes)
#     - review_and_fix_code (code review)

# %%
# ============================================================================
# EXECUTE AGENT
# ============================================================================

result = agent.run()
print(f"\n🎯 Agent Output:\n{result}")
# Out:
# 🛠️  Preparing workspace...
#
# 🚀 Starting Terraform Code Generation Agent
# ================================================================================
# Timestamp: 2026-05-11 14:00:55
# ================================================================================
#
# 📝 Agent is running...
#     (Agent will autonomously call: terraform_init, terraform_validate, terraform_plan, review_and_fix_code)
# --------------------------------------------------------------------------------
# 14:00:58 - httpx - INFO - HTTP Request: POST https://api.anthropic.com/v1/messages "HTTP/1.1 200 OK"
# 14:00:58 - terraform_agent.tools - DEBUG - search_knowledge_base called with query: GCS security best practices IAM lifecycle rules
# 14:00:58 - terraform_agent.tools - INFO - Searching knowledge base for: GCS security best practices IAM lifecycle rules
# 14:00:58 - terraform_agent.tools - DEBUG - load_module_spec called with file_path: docs-modules/cloud-storage.md
# 14:00:58 - terraform_agent.tools - DEBUG - search_knowledge_base called with query: Terraform module structure variables outputs naming conventions
# 14:00:58 - terraform_agent.tools - INFO - Searching knowledge base for: Terraform module structure variables outputs naming conventions
# 14:00:58 - terraform_agent.tools - INFO - Loading module spec from: /Users/melkouhen/audit-tools/test-langchain/docs-modules/cloud-storage.md
# 14:00:58 - terraform_agent.tools - INFO - Module spec loaded successfully (2161 bytes)
# 14:00:58 - httpx - INFO - HTTP Request: POST http://127.0.0.1:11434/api/embed "HTTP/1.1 200 OK"
# 14:00:58 - terraform_agent.tools - INFO - Knowledge base search completed in 0.07s
# 14:00:58 - httpx - INFO - HTTP Request: POST http://127.0.0.1:11434/api/embed "HTTP/1.1 200 OK"
# 14:00:58 - terraform_agent.tools - INFO - Knowledge base search completed in 0.07s
# 14:01:17 - httpx - INFO - HTTP Request: POST https://api.anthropic.com/v1/messages "HTTP/1.1 200 OK"
# 14:01:19 - httpx - INFO - HTTP Request: POST https://api.anthropic.com/v1/messages "HTTP/1.1 200 OK"
# 14:01:19 - terraform_agent.tools - DEBUG - terraform_init called with path: /tmp/work/envs/dev
# 14:01:19 - terraform_agent.tools - INFO - Running terraform init in dev environment at /tmp/work/envs/dev
# 14:01:19 - terraform_agent.tools - DEBUG - Executing: terraform init
# 🔧 Running terraform init in /tmp/work/envs/dev...
# 14:01:23 - terraform_agent.tools - INFO - terraform init successful in 3.41s
# 14:01:24 - httpx - INFO - HTTP Request: POST https://api.anthropic.com/v1/messages "HTTP/1.1 200 OK"
# 14:01:24 - terraform_agent.tools - DEBUG - terraform_validate called with path: /tmp/work/envs/dev
# 14:01:24 - terraform_agent.tools - INFO - Running terraform validate in dev environment at /tmp/work/envs/dev
# 14:01:24 - terraform_agent.tools - DEBUG - Executing: terraform validate
# 14:01:26 - terraform_agent.tools - ERROR - terraform validate failed (exit code 1) after 1.63s
# 14:01:26 - terraform_agent.tools - DEBUG - Validation output: ╷
# │ Error: Unsupported attribute
# │
# │   on ../../modules/gcs_bucket/outputs.tf line 13, in output "bucket_self_links":
# │   13:   value       = module.gcs_bucket.buckets_self_link
# │     ├────────────────
# │     │ module.gcs_bucket is object with 11 attributes
# │
# │ This object does not have an attribute named "buckets_self_link".
# ╵
#
# 14:01:28 - httpx - INFO - HTTP Request: POST https://api.anthropic.com/v1/messages "HTTP/1.1 200 OK"
# 14:01:30 - httpx - INFO - HTTP Request: POST https://api.anthropic.com/v1/messages "HTTP/1.1 200 OK"
# 14:01:32 - httpx - INFO - HTTP Request: POST https://api.anthropic.com/v1/messages "HTTP/1.1 200 OK"
# 14:01:36 - httpx - INFO - HTTP Request: POST https://api.anthropic.com/v1/messages "HTTP/1.1 200 OK"
# 14:01:36 - terraform_agent.tools - DEBUG - terraform_init called with path: /tmp/work/envs/dev
# 14:01:36 - terraform_agent.tools - DEBUG - terraform_validate called with path: /tmp/work/envs/dev
# 14:01:36 - terraform_agent.tools - INFO - Running terraform init in dev environment at /tmp/work/envs/dev
# 14:01:36 - terraform_agent.tools - INFO - Running terraform validate in dev environment at /tmp/work/envs/dev
# 14:01:36 - terraform_agent.tools - DEBUG - Executing: terraform validate
# 14:01:36 - terraform_agent.tools - DEBUG - Executing: terraform init
# 🔧 Running terraform init in /tmp/work/envs/dev...
# 14:01:37 - terraform_agent.tools - INFO - terraform init successful in 0.38s
# 14:01:37 - terraform_agent.tools - INFO - terraform validate successful in 0.41s
# 14:01:39 - httpx - INFO - HTTP Request: POST https://api.anthropic.com/v1/messages "HTTP/1.1 200 OK"
# 14:01:39 - terraform_agent.tools - DEBUG - terraform_plan called with path: /tmp/work/envs/dev
# 14:01:39 - terraform_agent.tools - INFO - Running terraform plan in dev environment at /tmp/work/envs/dev
# 14:01:39 - terraform_agent.tools - DEBUG - Executing: terraform plan -no-color
# 14:01:39 - terraform_agent.tools - ERROR - terraform plan failed (exit code 1) after 0.66s
# 14:01:39 - terraform_agent.tools - DEBUG - Plan output:
# Planning failed. Terraform encountered an error while generating this plan.
#
# ...
# 14:01:43 - httpx - INFO - HTTP Request: POST https://api.anthropic.com/v1/messages "HTTP/1.1 200 OK"
# 14:01:46 - httpx - INFO - HTTP Request: POST https://api.anthropic.com/v1/messages "HTTP/1.1 200 OK"
# 14:01:48 - httpx - INFO - HTTP Request: POST https://api.anthropic.com/v1/messages "HTTP/1.1 200 OK"
# 14:01:48 - terraform_agent.tools - DEBUG - terraform_init called with path: /tmp/work/envs/dev
# 14:01:48 - terraform_agent.tools - INFO - Running terraform init in dev environment at /tmp/work/envs/dev
# 14:01:48 - terraform_agent.tools - DEBUG - Executing: terraform init
# 14:01:48 - terraform_agent.tools - DEBUG - terraform_validate called with path: /tmp/work/envs/dev
# 14:01:48 - terraform_agent.tools - DEBUG - terraform_plan called with path: /tmp/work/envs/dev
# 14:01:48 - terraform_agent.tools - INFO - Running terraform plan in dev environment at /tmp/work/envs/dev
# 14:01:48 - terraform_agent.tools - DEBUG - Executing: terraform plan -no-color
# 14:01:48 - terraform_agent.tools - INFO - Running terraform validate in dev environment at /tmp/work/envs/dev
# 14:01:48 - terraform_agent.tools - DEBUG - Executing: terraform validate
# 🔧 Running terraform init in /tmp/work/envs/dev...
# 14:01:48 - terraform_agent.tools - INFO - terraform init successful in 0.38s
# 14:01:48 - terraform_agent.tools - INFO - terraform validate successful in 0.38s
# 14:01:48 - terraform_agent.tools - ERROR - terraform plan failed (exit code 1) after 0.72s
# 14:01:48 - terraform_agent.tools - DEBUG - Plan output:
# Planning failed. Terraform encountered an error while generating this plan.
#
# ...
# 14:01:51 - httpx - INFO - HTTP Request: POST https://api.anthropic.com/v1/messages "HTTP/1.1 200 OK"
# 14:01:55 - httpx - INFO - HTTP Request: POST https://api.anthropic.com/v1/messages "HTTP/1.1 200 OK"
# 14:01:57 - httpx - INFO - HTTP Request: POST https://api.anthropic.com/v1/messages "HTTP/1.1 200 OK"
# 14:01:57 - terraform_agent.tools - DEBUG - terraform_plan called with path: /tmp/work/envs/dev
# 14:01:57 - terraform_agent.tools - INFO - Running terraform plan in dev environment at /tmp/work/envs/dev
# 14:01:57 - terraform_agent.tools - DEBUG - Executing: terraform plan -no-color
# 14:01:57 - terraform_agent.tools - DEBUG - terraform_init called with path: /tmp/work/envs/dev
# 14:01:57 - terraform_agent.tools - DEBUG - terraform_validate called with path: /tmp/work/envs/dev
# 14:01:57 - terraform_agent.tools - INFO - Running terraform validate in dev environment at /tmp/work/envs/dev
# 14:01:57 - terraform_agent.tools - DEBUG - Executing: terraform validate
# 14:01:57 - terraform_agent.tools - INFO - Running terraform init in dev environment at /tmp/work/envs/dev
# 14:01:57 - terraform_agent.tools - DEBUG - Executing: terraform init
# 🔧 Running terraform init in /tmp/work/envs/dev...
# 14:01:57 - terraform_agent.tools - INFO - terraform validate successful in 0.37s
# 14:01:57 - terraform_agent.tools - INFO - terraform init successful in 0.38s
# 14:01:58 - terraform_agent.tools - INFO - terraform plan successful in 0.68s
# 14:02:00 - httpx - INFO - HTTP Request: POST https://api.anthropic.com/v1/messages "HTTP/1.1 200 OK"
# 14:02:00 - terraform_agent.tools - DEBUG - review_and_fix_code called with path: /tmp/work/envs/dev
# 14:02:00 - terraform_agent.tools - INFO - Starting code review at /tmp/work/envs/dev
# 14:02:00 - terraform_agent.tools - DEBUG - Step 1: Retrieving best practices from knowledge base
# 14:02:00 - httpx - INFO - HTTP Request: POST http://127.0.0.1:11434/api/embed "HTTP/1.1 200 OK"
# 14:02:00 - terraform_agent.tools - DEBUG - Retrieved 2738 characters of best practices
# 14:02:00 - terraform_agent.tools - DEBUG - Step 2: Reading Terraform files
# 14:02:00 - terraform_agent.tools - INFO - Found 4 Terraform files
# 14:02:00 - terraform_agent.tools - DEBUG - Loaded main.tf: 338 bytes
# 14:02:00 - terraform_agent.tools - DEBUG - Loaded outputs.tf: 374 bytes
# 14:02:00 - terraform_agent.tools - DEBUG - Loaded providers.tf: 292 bytes
# 14:02:00 - terraform_agent.tools - DEBUG - Loaded variables.tf: 835 bytes
# 14:02:00 - terraform_agent.tools - INFO - Total code to review: 1924 bytes across 4 files
# 14:02:00 - terraform_agent.tools - DEBUG - Step 3: Preparing review prompt
# 14:02:00 - terraform_agent.tools - DEBUG - Review prompt prepared: 3524 bytes
# 14:02:00 - terraform_agent.tools - INFO - Step 4: Running code review with claude-haiku-4-5-20251001
# 14:02:00 - httpx - INFO - HTTP Request: POST http://127.0.0.1:11434/api/chat "HTTP/1.1 404 Not Found"
# ❌ Agent Error: model 'claude-haiku-4-5-20251001' not found (status code: 404)
# ❌ FAILED
# --------------------------------------------------------------------------------
#
# 🎯 Agent Output:
# model 'claude-haiku-4-5-20251001' not found (status code: 404)
# Traceback (most recent call last):
#   File "/Users/melkouhen/audit-tools/test-langchain/terraform_agent/agent.py", line 139, in run
#     result = self.agent.invoke(
#         {"messages": messages}
#     )
#   File "/Users/melkouhen/audit-tools/test-langchain/.venv/lib/python3.14/site-packages/langgraph/pregel/main.py", line 3365, in invoke
#     for chunk in self.stream(
#                  ~~~~~~~~~~~^
#         input,
#         ^^^^^^
#     ...<10 lines>...
#         **kwargs,
#         ^^^^^^^^^
#     ):
#     ^
#   File "/Users/melkouhen/audit-tools/test-langchain/.venv/lib/python3.14/site-packages/langgraph/pregel/main.py", line 2759, in stream
#     for _ in runner.tick(
#              ~~~~~~~~~~~^
#         [t for t in loop.tasks.values() if not t.writes],
#         ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#     ...<2 lines>...
#         schedule_task=loop.accept_push,
#         ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#     ):
#     ^
#   File "/Users/melkouhen/audit-tools/test-langchain/.venv/lib/python3.14/site-packages/langgraph/pregel/_runner.py", line 167, in tick
#     run_with_retry(
#     ~~~~~~~~~~~~~~^
#         t,
#         ^^
#     ...<10 lines>...
#         },
#         ^^
#     )
#     ^
#   File "/Users/melkouhen/audit-tools/test-langchain/.venv/lib/python3.14/site-packages/langgraph/pregel/_retry.py", line 126, in run_with_retry
#     return task.proc.invoke(task.input, config)
#            ~~~~~~~~~~~~~~~~^^^^^^^^^^^^^^^^^^^^
#   File "/Users/melkouhen/audit-tools/test-langchain/.venv/lib/python3.14/site-packages/langgraph/_internal/_runnable.py", line 656, in invoke
#     input = context.run(step.invoke, input, config, **kwargs)
#   File "/Users/melkouhen/audit-tools/test-langchain/.venv/lib/python3.14/site-packages/langgraph/_internal/_runnable.py", line 400, in invoke
#     ret = self.func(*args, **kwargs)
#   File "/Users/melkouhen/audit-tools/test-langchain/.venv/lib/python3.14/site-packages/langgraph/prebuilt/tool_node.py", line 821, in _func
#     outputs = list(
#         executor.map(self._run_one, tool_calls, input_types, tool_runtimes)
#     )
#   File "/opt/homebrew/Cellar/python@3.14/3.14.4_1/Frameworks/Python.framework/Versions/3.14/lib/python3.14/concurrent/futures/_base.py", line 639, in result_iterator
#     yield _result_or_cancel(fs.pop())
#           ~~~~~~~~~~~~~~~~~^^^^^^^^^^
#   File "/opt/homebrew/Cellar/python@3.14/3.14.4_1/Frameworks/Python.framework/Versions/3.14/lib/python3.14/concurrent/futures/_base.py", line 311, in _result_or_cancel
#     return fut.result(timeout)
#            ~~~~~~~~~~^^^^^^^^^
#   File "/opt/homebrew/Cellar/python@3.14/3.14.4_1/Frameworks/Python.framework/Versions/3.14/lib/python3.14/concurrent/futures/_base.py", line 450, in result
#     return self.__get_result()
#            ~~~~~~~~~~~~~~~~~^^
#   File "/opt/homebrew/Cellar/python@3.14/3.14.4_1/Frameworks/Python.framework/Versions/3.14/lib/python3.14/concurrent/futures/_base.py", line 395, in __get_result
#     raise self._exception
#   File "/opt/homebrew/Cellar/python@3.14/3.14.4_1/Frameworks/Python.framework/Versions/3.14/lib/python3.14/concurrent/futures/thread.py", line 86, in run
#     result = ctx.run(self.task)
#   File "/opt/homebrew/Cellar/python@3.14/3.14.4_1/Frameworks/Python.framework/Versions/3.14/lib/python3.14/concurrent/futures/thread.py", line 73, in run
#     return fn(*args, **kwargs)
#   File "/Users/melkouhen/audit-tools/test-langchain/.venv/lib/python3.14/site-packages/langchain_core/runnables/config.py", line 610, in _wrapped_fn
#     return contexts.pop().run(fn, *args)
#            ~~~~~~~~~~~~~~~~~~^^^^^^^^^^^
#   File "/Users/melkouhen/audit-tools/test-langchain/.venv/lib/python3.14/site-packages/langgraph/prebuilt/tool_node.py", line 1060, in _run_one
#     content = _handle_tool_error(e, flag=self._handle_tool_errors)
#   File "/Users/melkouhen/audit-tools/test-langchain/.venv/lib/python3.14/site-packages/langgraph/prebuilt/tool_node.py", line 433, in _handle_tool_error
#     content = flag(e)  # type: ignore [assignment, call-arg]
#   File "/Users/melkouhen/audit-tools/test-langchain/.venv/lib/python3.14/site-packages/langgraph/prebuilt/tool_node.py", line 390, in _default_handle_tool_errors
#     raise e
#   File "/Users/melkouhen/audit-tools/test-langchain/.venv/lib/python3.14/site-packages/langgraph/prebuilt/tool_node.py", line 1054, in _run_one
#     return self._wrap_tool_call(tool_request, execute)
#            ~~~~~~~~~~~~~~~~~~~~^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/melkouhen/audit-tools/test-langchain/.venv/lib/python3.14/site-packages/deepagents/middleware/filesystem.py", line 1676, in wrap_tool_call
#     tool_result = handler(request)
#   File "/Users/melkouhen/audit-tools/test-langchain/.venv/lib/python3.14/site-packages/langgraph/prebuilt/tool_node.py", line 1050, in execute
#     return self._execute_tool_sync(req, input_type, config)
#            ~~~~~~~~~~~~~~~~~~~~~~~^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/melkouhen/audit-tools/test-langchain/.venv/lib/python3.14/site-packages/langgraph/prebuilt/tool_node.py", line 1005, in _execute_tool_sync
#     content = _handle_tool_error(e, flag=self._handle_tool_errors)
#   File "/Users/melkouhen/audit-tools/test-langchain/.venv/lib/python3.14/site-packages/langgraph/prebuilt/tool_node.py", line 433, in _handle_tool_error
#     content = flag(e)  # type: ignore [assignment, call-arg]
#   File "/Users/melkouhen/audit-tools/test-langchain/.venv/lib/python3.14/site-packages/langgraph/prebuilt/tool_node.py", line 390, in _default_handle_tool_errors
#     raise e
#   File "/Users/melkouhen/audit-tools/test-langchain/.venv/lib/python3.14/site-packages/langgraph/prebuilt/tool_node.py", line 957, in _execute_tool_sync
#     response = tool.invoke(call_args, config)
#   File "/Users/melkouhen/audit-tools/test-langchain/.venv/lib/python3.14/site-packages/langchain_core/tools/base.py", line 642, in invoke
#     return self.run(tool_input, **kwargs)
#            ~~~~~~~~^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/melkouhen/audit-tools/test-langchain/.venv/lib/python3.14/site-packages/langchain_core/tools/base.py", line 1001, in run
#     raise error_to_raise
#   File "/Users/melkouhen/audit-tools/test-langchain/.venv/lib/python3.14/site-packages/langchain_core/tools/base.py", line 967, in run
#     response = context.run(self._run, *tool_args, **tool_kwargs)
#   File "/Users/melkouhen/audit-tools/test-langchain/.venv/lib/python3.14/site-packages/langchain_core/tools/structured.py", line 97, in _run
#     return self.func(*args, **kwargs)
#            ~~~~~~~~~^^^^^^^^^^^^^^^^^
#   File "/Users/melkouhen/audit-tools/test-langchain/terraform_agent/tools.py", line 331, in review_and_fix_code
#     review_response = str(_review_model.invoke(review_prompt).content)
#                           ~~~~~~~~~~~~~~~~~~~~^^^^^^^^^^^^^^^
#   File "/Users/melkouhen/audit-tools/test-langchain/.venv/lib/python3.14/site-packages/langchain_core/language_models/chat_models.py", line 471, in invoke
#     self.generate_prompt(
#     ~~~~~~~~~~~~~~~~~~~~^
#         [self._convert_input(input)],
#         ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#     ...<6 lines>...
#         **kwargs,
#         ^^^^^^^^^
#     ).generations[0][0],
#     ^
#   File "/Users/melkouhen/audit-tools/test-langchain/.venv/lib/python3.14/site-packages/langchain_core/language_models/chat_models.py", line 1749, in generate_prompt
#     return self.generate(prompt_messages, stop=stop, callbacks=callbacks, **kwargs)
#            ~~~~~~~~~~~~~^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/melkouhen/audit-tools/test-langchain/.venv/lib/python3.14/site-packages/langchain_core/language_models/chat_models.py", line 1556, in generate
#     self._generate_with_cache(
#     ~~~~~~~~~~~~~~~~~~~~~~~~~^
#         m,
#         ^^
#     ...<2 lines>...
#         **kwargs,
#         ^^^^^^^^^
#     )
#     ^
#   File "/Users/melkouhen/audit-tools/test-langchain/.venv/lib/python3.14/site-packages/langchain_core/language_models/chat_models.py", line 1896, in _generate_with_cache
#     result = self._generate(
#         messages, stop=stop, run_manager=run_manager, **kwargs
#     )
#   File "/Users/melkouhen/audit-tools/test-langchain/.venv/lib/python3.14/site-packages/langchain_ollama/chat_models.py", line 1200, in _generate
#     final_chunk = self._chat_stream_with_aggregation(
#         messages, stop, run_manager, verbose=self.verbose, **kwargs
#     )
#   File "/Users/melkouhen/audit-tools/test-langchain/.venv/lib/python3.14/site-packages/langchain_ollama/chat_models.py", line 1135, in _chat_stream_with_aggregation
#     for chunk in self._iterate_over_stream(messages, stop, **kwargs):
#                  ~~~~~~~~~~~~~~~~~~~~~~~~~^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/melkouhen/audit-tools/test-langchain/.venv/lib/python3.14/site-packages/langchain_ollama/chat_models.py", line 1224, in _iterate_over_stream
#     for stream_resp in self._create_chat_stream(messages, stop, **kwargs):
#                        ~~~~~~~~~~~~~~~~~~~~~~~~^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/melkouhen/audit-tools/test-langchain/.venv/lib/python3.14/site-packages/langchain_ollama/chat_models.py", line 1122, in _create_chat_stream
#     yield from self._client.chat(**chat_params)
#   File "/Users/melkouhen/audit-tools/test-langchain/.venv/lib/python3.14/site-packages/ollama/_client.py", line 179, in inner
#     raise ResponseError(e.response.text, e.response.status_code) from None
# ollama._types.ResponseError: model 'claude-haiku-4-5-20251001' not found (status code: 404)
# During task with name 'tools' and id '256cbffc-962c-542f-c8d8-cb1efa5e34f8'
