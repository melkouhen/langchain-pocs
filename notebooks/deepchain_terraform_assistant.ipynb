# %%
# ============================================================================
# TERRAFORM CODE GENERATION & VALIDATION AGENT
# ============================================================================

from pathlib import Path
from dotenv import load_dotenv

# Load environment variables
load_dotenv()

# Import agent classes
import sys
sys.path.insert(0, str(Path.cwd().parent))

from terraform_agent import Config, PromptManager, KnowledgeBase, TerraformAgent

print("✓ All imports loaded successfully")
# Out:
# ✓ All imports loaded successfully

# %%
# ============================================================================
# CONFIGURE LOGGING
# ============================================================================

import logging

# Configure logging to see all DEBUG and above messages
logging.basicConfig(
    level=logging.INFO,
    format='%(asctime)s - %(name)s - %(levelname)s - %(message)s',
    datefmt='%H:%M:%S'
)

# Optional: Set specific loggers to DEBUG for more detail
logging.getLogger('terraform_agent').setLevel(logging.DEBUG)

print("✓ Logging configured - you will now see INFO level logs and above")
# Out:
# ✓ Logging configured - you will now see INFO level logs and above

# %%
# ============================================================================
# INITIALIZE COMPONENTS
# ============================================================================

# Get project root (parent of notebooks directory)
project_root = Path.cwd().parent

# Initialize configuration
config = Config(base_dir=project_root)
print(f"Project Root: {config.PROJECT_ROOT}")
print(f"Work Dir: {config.WORK_DIR}")
print(f"Docs Dir: {config.RULES_DIR}")

# Initialize prompt manager
prompts = PromptManager(config)
print("\n✓ Prompts loaded")

# Initialize knowledge base (loads and indexes docs)
knowledge_base = KnowledgeBase(config)

# Initialize agent
agent = TerraformAgent(config, prompts, knowledge_base)
# Out:
# 15:49:11 - terraform_agent.tools - INFO - Initializing tools with config, prompts, and knowledge base
# 15:49:11 - terraform_agent.tools - INFO - Tools initialized - Review model: qwen2.5-coder:7b-instruct
# Project Root: /Users/melkouhen/audit-tools/test-langchain
# Work Dir: /Users/melkouhen/audit-tools/test-langchain/work
# Docs Dir: /Users/melkouhen/audit-tools/test-langchain/rules
#
# ✓ Prompts loaded
# 📚 Loading knowledge base...
#   ✓ Loaded 12 document(s) from /Users/melkouhen/audit-tools/test-langchain/rules
#   ✓ Split into 121 chunks
#   ✓ Vectorstore found, loading existing database...
#   ✓ Vectorstore already indexed with 80 documents
#   ✓ Vectorstore created and indexed
# 🤖 Setting up agent...
#   ✓ System prompt loaded (3037 chars)
#   ✓ User prompt loaded (1033 chars)
#   ✓ Agent created with tools:
#     - load_module_spec (module specifications)
#     - search_knowledge_base (best practices)
#     - terraform_init (initialize working directory)
#     - terraform_validate (validate configuration)
#     - terraform_plan (preview changes)
#     - review_and_fix_code (code review)

# %%
# ============================================================================
# EXECUTE AGENT
# ============================================================================

# Load user prompt from file
prompt_filename = "prompts/terraform-user.md"  # Change filename as needed
user_prompt = (Path.cwd().parent / prompt_filename).read_text()

result = agent.run(user_prompt=user_prompt)
print(f"\n🎯 Agent Output:\n{result}")
# Out:
# 🛠️  Preparing workspace...
#
# 🚀 Starting Terraform Code Generation Agent
# ================================================================================
# Timestamp: 2026-05-11 15:49:49
# ================================================================================
#
# 📝 Agent is running...
#     (Agent will autonomously call: terraform_init, terraform_validate, terraform_plan, review_and_fix_code)
# --------------------------------------------------------------------------------
# 15:49:52 - httpx - INFO - HTTP Request: POST https://api.anthropic.com/v1/messages "HTTP/1.1 200 OK"
# 15:49:52 - terraform_agent.tools - DEBUG - search_knowledge_base called with query: sécurité google_storage_bucket
# 15:49:52 - terraform_agent.tools - DEBUG - load_module_spec called with file_path: docs/terraform-module.md
# 15:49:52 - terraform_agent.tools - DEBUG - search_knowledge_base called with query: structure terraform environnements dev prod isolation
# 15:49:52 - terraform_agent.tools - DEBUG - search_knowledge_base called with query: nommage google_storage_bucket conventions
# 15:49:52 - terraform_agent.tools - INFO - Searching knowledge base for: sécurité google_storage_bucket
# 15:49:52 - terraform_agent.tools - INFO - Loading module spec from: /Users/melkouhen/audit-tools/test-langchain/docs/terraform-module.md
# 15:49:52 - terraform_agent.tools - INFO - Searching knowledge base for: structure terraform environnements dev prod isolation
# 15:49:52 - terraform_agent.tools - INFO - Searching knowledge base for: nommage google_storage_bucket conventions
# 15:49:52 - terraform_agent.tools - WARNING - Module spec file not found: /Users/melkouhen/audit-tools/test-langchain/docs/terraform-module.md
# 15:49:52 - httpx - INFO - HTTP Request: POST http://127.0.0.1:11434/api/embed "HTTP/1.1 200 OK"
# 15:49:52 - terraform_agent.tools - INFO - Knowledge base search completed in 0.06s
# 15:49:52 - httpx - INFO - HTTP Request: POST http://127.0.0.1:11434/api/embed "HTTP/1.1 200 OK"
# 15:49:52 - terraform_agent.tools - INFO - Knowledge base search completed in 0.07s
# 15:49:52 - httpx - INFO - HTTP Request: POST http://127.0.0.1:11434/api/embed "HTTP/1.1 200 OK"
# 15:49:52 - terraform_agent.tools - INFO - Knowledge base search completed in 0.08s
# 15:49:55 - httpx - INFO - HTTP Request: POST https://api.anthropic.com/v1/messages "HTTP/1.1 200 OK"
# 15:50:10 - httpx - INFO - HTTP Request: POST https://api.anthropic.com/v1/messages "HTTP/1.1 200 OK"
# 15:50:11 - httpx - INFO - HTTP Request: POST https://api.anthropic.com/v1/messages "HTTP/1.1 200 OK"
# 15:50:13 - httpx - INFO - HTTP Request: POST https://api.anthropic.com/v1/messages "HTTP/1.1 200 OK"
# 15:50:16 - httpx - INFO - HTTP Request: POST https://api.anthropic.com/v1/messages "HTTP/1.1 200 OK"
# 15:50:21 - httpx - INFO - HTTP Request: POST https://api.anthropic.com/v1/messages "HTTP/1.1 200 OK"
# 15:50:24 - httpx - INFO - HTTP Request: POST https://api.anthropic.com/v1/messages "HTTP/1.1 200 OK"
# 15:50:26 - httpx - INFO - HTTP Request: POST https://api.anthropic.com/v1/messages "HTTP/1.1 200 OK"
# 15:50:28 - httpx - INFO - HTTP Request: POST https://api.anthropic.com/v1/messages "HTTP/1.1 200 OK"
# 15:50:30 - httpx - INFO - HTTP Request: POST https://api.anthropic.com/v1/messages "HTTP/1.1 200 OK"
# 15:50:35 - httpx - INFO - HTTP Request: POST https://api.anthropic.com/v1/messages "HTTP/1.1 200 OK"
# 15:50:39 - httpx - INFO - HTTP Request: POST https://api.anthropic.com/v1/messages "HTTP/1.1 200 OK"
# 15:50:41 - httpx - INFO - HTTP Request: POST https://api.anthropic.com/v1/messages "HTTP/1.1 200 OK"
# 15:50:43 - httpx - INFO - HTTP Request: POST https://api.anthropic.com/v1/messages "HTTP/1.1 200 OK"
# 15:50:45 - httpx - INFO - HTTP Request: POST https://api.anthropic.com/v1/messages "HTTP/1.1 200 OK"
# 15:50:47 - httpx - INFO - HTTP Request: POST https://api.anthropic.com/v1/messages "HTTP/1.1 200 OK"
# 15:50:48 - httpx - INFO - HTTP Request: POST https://api.anthropic.com/v1/messages "HTTP/1.1 200 OK"
# 15:50:53 - httpx - INFO - HTTP Request: POST https://api.anthropic.com/v1/messages "HTTP/1.1 200 OK"
# 15:50:54 - httpx - INFO - HTTP Request: POST https://api.anthropic.com/v1/messages "HTTP/1.1 200 OK"
# 15:50:54 - terraform_agent.tools - DEBUG - terraform_init called with path: /Users/melkouhen/audit-tools/test-langchain/work/envs/dev
# 15:50:54 - terraform_agent.tools - INFO - Running terraform init in dev environment at /Users/melkouhen/audit-tools/test-langchain/work/envs/dev
# 15:50:54 - terraform_agent.tools - DEBUG - Executing: terraform init
# 15:50:55 - terraform_agent.tools - ERROR - terraform init failed (exit code 1) after 0.28s
# 15:50:55 - terraform_agent.tools - DEBUG - Init output: Initializing modules...
#
# 15:50:57 - httpx - INFO - HTTP Request: POST https://api.anthropic.com/v1/messages "HTTP/1.1 200 OK"
# 15:50:58 - httpx - INFO - HTTP Request: POST https://api.anthropic.com/v1/messages "HTTP/1.1 200 OK"
# 15:51:00 - httpx - INFO - HTTP Request: POST https://api.anthropic.com/v1/messages "HTTP/1.1 200 OK"
# 15:51:03 - httpx - INFO - HTTP Request: POST https://api.anthropic.com/v1/messages "HTTP/1.1 200 OK"
# 15:51:05 - httpx - INFO - HTTP Request: POST https://api.anthropic.com/v1/messages "HTTP/1.1 200 OK"
# 15:51:07 - httpx - INFO - HTTP Request: POST https://api.anthropic.com/v1/messages "HTTP/1.1 200 OK"
# 15:51:09 - httpx - INFO - HTTP Request: POST https://api.anthropic.com/v1/messages "HTTP/1.1 200 OK"
# 15:51:11 - httpx - INFO - HTTP Request: POST https://api.anthropic.com/v1/messages "HTTP/1.1 200 OK"
# 15:51:13 - httpx - INFO - HTTP Request: POST https://api.anthropic.com/v1/messages "HTTP/1.1 200 OK"
# 15:51:13 - terraform_agent.tools - DEBUG - terraform_init called with path: /Users/melkouhen/audit-tools/test-langchain/work/envs/dev
# 15:51:13 - terraform_agent.tools - INFO - Running terraform init in dev environment at /Users/melkouhen/audit-tools/test-langchain/work/envs/dev
# 15:51:13 - terraform_agent.tools - DEBUG - Executing: terraform init
# 15:51:13 - terraform_agent.tools - ERROR - terraform init failed (exit code 1) after 0.22s
# 15:51:13 - terraform_agent.tools - DEBUG - Init output: Initializing modules...
#
# 15:51:15 - httpx - INFO - HTTP Request: POST https://api.anthropic.com/v1/messages "HTTP/1.1 200 OK"
# 15:51:18 - httpx - INFO - HTTP Request: POST https://api.anthropic.com/v1/messages "HTTP/1.1 200 OK"
# 15:51:21 - httpx - INFO - HTTP Request: POST https://api.anthropic.com/v1/messages "HTTP/1.1 200 OK"
# 15:51:23 - httpx - INFO - HTTP Request: POST https://api.anthropic.com/v1/messages "HTTP/1.1 200 OK"
# 15:51:23 - terraform_agent.tools - DEBUG - terraform_init called with path: /Users/melkouhen/audit-tools/test-langchain/work/envs/dev
# 15:51:23 - terraform_agent.tools - INFO - Running terraform init in dev environment at /Users/melkouhen/audit-tools/test-langchain/work/envs/dev
# 15:51:23 - terraform_agent.tools - DEBUG - Executing: terraform init
# 15:51:23 - terraform_agent.tools - ERROR - terraform init failed (exit code 1) after 0.05s
# 15:51:23 - terraform_agent.tools - DEBUG - Init output: Initializing modules...
#
# 15:51:27 - httpx - INFO - HTTP Request: POST https://api.anthropic.com/v1/messages "HTTP/1.1 200 OK"
# 15:51:27 - terraform_agent.tools - DEBUG - terraform_validate called with path: /Users/melkouhen/audit-tools/test-langchain/work/modules/gcs_bucket
# 15:51:27 - terraform_agent.tools - INFO - Running terraform validate in prod environment at /Users/melkouhen/audit-tools/test-langchain/work/modules/gcs_bucket
# 15:51:27 - terraform_agent.tools - WARNING - Skipping terraform validate: running in prod environment (only dev allowed)
# 15:51:30 - httpx - INFO - HTTP Request: POST https://api.anthropic.com/v1/messages "HTTP/1.1 200 OK"
# 15:51:32 - httpx - INFO - HTTP Request: POST https://api.anthropic.com/v1/messages "HTTP/1.1 200 OK"
# 15:51:34 - httpx - INFO - HTTP Request: POST https://api.anthropic.com/v1/messages "HTTP/1.1 200 OK"
# 15:51:37 - httpx - INFO - HTTP Request: POST https://api.anthropic.com/v1/messages "HTTP/1.1 200 OK"
# 15:51:38 - httpx - INFO - HTTP Request: POST https://api.anthropic.com/v1/messages "HTTP/1.1 200 OK"
# 15:51:40 - httpx - INFO - HTTP Request: POST https://api.anthropic.com/v1/messages "HTTP/1.1 200 OK"
# 15:51:42 - httpx - INFO - HTTP Request: POST https://api.anthropic.com/v1/messages "HTTP/1.1 200 OK"
# 15:51:42 - terraform_agent.tools - DEBUG - terraform_init called with path: /Users/melkouhen/audit-tools/test-langchain/work/envs/dev
# 15:51:42 - terraform_agent.tools - INFO - Running terraform init in dev environment at /Users/melkouhen/audit-tools/test-langchain/work/envs/dev
# 15:51:42 - terraform_agent.tools - DEBUG - Executing: terraform init
# 15:51:42 - terraform_agent.tools - ERROR - terraform init failed (exit code 1) after 0.04s
# 15:51:42 - terraform_agent.tools - DEBUG - Init output: Initializing modules...
#
# 15:51:43 - httpx - INFO - HTTP Request: POST https://api.anthropic.com/v1/messages "HTTP/1.1 200 OK"
# 15:51:43 - terraform_agent.tools - DEBUG - terraform_validate called with path: /Users/melkouhen/audit-tools/test-langchain/work/envs/dev
# 15:51:43 - terraform_agent.tools - INFO - Running terraform validate in dev environment at /Users/melkouhen/audit-tools/test-langchain/work/envs/dev
# 15:51:43 - terraform_agent.tools - DEBUG - Executing: terraform validate
# 15:51:43 - terraform_agent.tools - ERROR - terraform validate failed (exit code 1) after 0.04s
# 15:51:43 - terraform_agent.tools - DEBUG - Validation output: ╷
# │ Error: Duplicate required providers configuration
# │
# │   on versions.tf line 3, in terraform:
# │    3:   required_providers {
# │
# │ A module may have only one required providers configuration. The required
# │ providers were previously configured at providers.tf:3,3-21.
# ╵
#
# 15:51:51 - httpx - INFO - HTTP Request: POST https://api.anthropic.com/v1/messages "HTTP/1.1 200 OK"
# 15:51:52 - httpx - INFO - HTTP Request: POST https://api.anthropic.com/v1/messages "HTTP/1.1 200 OK"
# 15:51:55 - httpx - INFO - HTTP Request: POST https://api.anthropic.com/v1/messages "HTTP/1.1 200 OK"
# 15:51:58 - httpx - INFO - HTTP Request: POST https://api.anthropic.com/v1/messages "HTTP/1.1 200 OK"
# 15:52:02 - httpx - INFO - HTTP Request: POST https://api.anthropic.com/v1/messages "HTTP/1.1 200 OK"
# 15:52:05 - httpx - INFO - HTTP Request: POST https://api.anthropic.com/v1/messages "HTTP/1.1 200 OK"
# 15:52:07 - httpx - INFO - HTTP Request: POST https://api.anthropic.com/v1/messages "HTTP/1.1 200 OK"
# 15:52:10 - httpx - INFO - HTTP Request: POST https://api.anthropic.com/v1/messages "HTTP/1.1 200 OK"
# 15:52:12 - httpx - INFO - HTTP Request: POST https://api.anthropic.com/v1/messages "HTTP/1.1 200 OK"
# 15:52:15 - httpx - INFO - HTTP Request: POST https://api.anthropic.com/v1/messages "HTTP/1.1 200 OK"
# 15:52:17 - httpx - INFO - HTTP Request: POST https://api.anthropic.com/v1/messages "HTTP/1.1 200 OK"
# 15:52:19 - httpx - INFO - HTTP Request: POST https://api.anthropic.com/v1/messages "HTTP/1.1 200 OK"
# 15:52:20 - httpx - INFO - HTTP Request: POST https://api.anthropic.com/v1/messages "HTTP/1.1 200 OK"
# 15:52:22 - httpx - INFO - HTTP Request: POST https://api.anthropic.com/v1/messages "HTTP/1.1 200 OK"
# 15:52:25 - httpx - INFO - HTTP Request: POST https://api.anthropic.com/v1/messages "HTTP/1.1 200 OK"
# 15:52:29 - httpx - INFO - HTTP Request: POST https://api.anthropic.com/v1/messages "HTTP/1.1 200 OK"
# 15:52:30 - httpx - INFO - HTTP Request: POST https://api.anthropic.com/v1/messages "HTTP/1.1 200 OK"
# 15:52:34 - httpx - INFO - HTTP Request: POST https://api.anthropic.com/v1/messages "HTTP/1.1 200 OK"
# 15:52:40 - httpx - INFO - HTTP Request: POST https://api.anthropic.com/v1/messages "HTTP/1.1 200 OK"
# 15:52:47 - httpx - INFO - HTTP Request: POST https://api.anthropic.com/v1/messages "HTTP/1.1 200 OK"
# 15:52:50 - httpx - INFO - HTTP Request: POST https://api.anthropic.com/v1/messages "HTTP/1.1 200 OK"
# 15:52:56 - httpx - INFO - HTTP Request: POST https://api.anthropic.com/v1/messages "HTTP/1.1 200 OK"
# 15:52:57 - terraform_agent.tools - DEBUG - terraform_init called with path: /Users/melkouhen/audit-tools/test-langchain/work/envs/dev
# 15:52:57 - terraform_agent.tools - INFO - Running terraform init in dev environment at /Users/melkouhen/audit-tools/test-langchain/work/envs/dev
# 15:52:57 - terraform_agent.tools - DEBUG - Executing: terraform init
# 15:52:57 - terraform_agent.tools - ERROR - terraform init failed (exit code 1) after 0.06s
# 15:52:57 - terraform_agent.tools - DEBUG - Init output: Initializing modules...
#
# 15:52:58 - httpx - INFO - HTTP Request: POST https://api.anthropic.com/v1/messages "HTTP/1.1 200 OK"
# 15:53:00 - httpx - INFO - HTTP Request: POST https://api.anthropic.com/v1/messages "HTTP/1.1 200 OK"
# 15:53:05 - httpx - INFO - HTTP Request: POST https://api.anthropic.com/v1/messages "HTTP/1.1 200 OK"
# 15:53:07 - httpx - INFO - HTTP Request: POST https://api.anthropic.com/v1/messages "HTTP/1.1 200 OK"
# 15:53:09 - httpx - INFO - HTTP Request: POST https://api.anthropic.com/v1/messages "HTTP/1.1 200 OK"
# 15:53:09 - terraform_agent.tools - DEBUG - terraform_init called with path: /Users/melkouhen/audit-tools/test-langchain/work/envs/dev
# 15:53:09 - terraform_agent.tools - INFO - Running terraform init in dev environment at /Users/melkouhen/audit-tools/test-langchain/work/envs/dev
# 15:53:09 - terraform_agent.tools - DEBUG - Executing: terraform init
# 15:53:09 - terraform_agent.tools - ERROR - terraform init failed (exit code 1) after 0.07s
# 15:53:09 - terraform_agent.tools - DEBUG - Init output: Initializing modules...
# Initializing provider plugins found in the configuration...
# - Reusing previous version of hashicorp/google from the dependency lock file
#
# 15:53:15 - httpx - INFO - HTTP Request: POST https://api.anthropic.com/v1/messages "HTTP/1.1 200 OK"
# 15:53:17 - httpx - INFO - HTTP Request: POST https://api.anthropic.com/v1/messages "HTTP/1.1 200 OK"
# 15:53:20 - httpx - INFO - HTTP Request: POST https://api.anthropic.com/v1/messages "HTTP/1.1 200 OK"
# 15:53:21 - httpx - INFO - HTTP Request: POST https://api.anthropic.com/v1/messages "HTTP/1.1 200 OK"
# 15:53:22 - terraform_agent.tools - DEBUG - terraform_init called with path: /Users/melkouhen/audit-tools/test-langchain/work/envs/dev
# 15:53:22 - terraform_agent.tools - INFO - Running terraform init in dev environment at /Users/melkouhen/audit-tools/test-langchain/work/envs/dev
# 15:53:22 - terraform_agent.tools - DEBUG - Executing: terraform init
# 15:53:22 - terraform_agent.tools - INFO - terraform init successful in 0.37s
# 15:53:24 - httpx - INFO - HTTP Request: POST https://api.anthropic.com/v1/messages "HTTP/1.1 200 OK"
# 15:53:24 - terraform_agent.tools - DEBUG - terraform_init called with path: /Users/melkouhen/audit-tools/test-langchain/work/envs/prod
# 15:53:24 - terraform_agent.tools - INFO - Running terraform init in prod environment at /Users/melkouhen/audit-tools/test-langchain/work/envs/prod
# 15:53:24 - terraform_agent.tools - WARNING - Skipping terraform init: running in prod environment (only dev allowed)
# 15:53:28 - httpx - INFO - HTTP Request: POST https://api.anthropic.com/v1/messages "HTTP/1.1 200 OK"
# 15:53:52 - httpx - INFO - HTTP Request: POST https://api.anthropic.com/v1/messages "HTTP/1.1 200 OK"
# 15:54:10 - httpx - INFO - HTTP Request: POST https://api.anthropic.com/v1/messages "HTTP/1.1 200 OK"
# 15:54:13 - httpx - INFO - HTTP Request: POST https://api.anthropic.com/v1/messages "HTTP/1.1 200 OK"
